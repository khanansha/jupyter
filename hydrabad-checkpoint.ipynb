# %%
import numpy as np
import pandas as pd
import itertools
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
from pandas.io.json import json_normalize
import json

# %%
with open('C:/Users/akhan.extern/Desktop/jsondata/hydrabad.json',encoding="utf8") as json_data:
    sample_object = json.load(json_data)

df = pd.io.json.json_normalize(sample_object)
df.columns = df.columns.map(lambda x: x.split(".")[-1])

print(df.shape)
# Out:
# (36, 58)

# %%
df
# Out:
#       HotelId                                    HotelName CategoryList  \
# 0   H!0129576                              Hampshire Plaza         None
# 1   H!0443764                       Minerva Grand Kondapur         None
# 2   H!0488389                        Mercure Hyderabad KCP         None
# 3   H!0100838                                 The Golkonda         None
# 4   H!0282309                         Park Hyatt Hyderabad         None
# 5   H!0282300                       Golkonda Resorts & Spa         None
# 6   H!0077709                                  Taj Krishna         None
# 7   H!0242122                                         Kens         None
# 8   H!0071936                                  The Manohar         None
# 9   H!0101661                                  Taj Banjara         None
# 10  H!0369986                   Hyatt Hyderabad Gachibowli         None
# 11  H!0247626                        Fortune Park Vallabha         None
# ...

# %%
df.columns
# Out:
# Index(['HotelId', 'HotelName', 'CategoryList', 'PropertyType', 'IsPrime',
#        'Description', 'HotelChain', 'StarRating', 'Rooms', 'MinRate', 'RPH',
#        'WebService', 'HotelAddress', 'PostalCode', 'City', 'LocationInfo',
#        'PhoneNumber', 'Fax', 'Email', 'Website', 'Checkintime', 'Checkouttime',
#        'CreditCards', 'HotelServices', 'RoomServices', 'Facilities',
#        'CountryCode', 'AirportCode', 'SupplierType', 'PropertyCategory',
#        'Provider', 'RoomDetails', 'HotelImages', 'HotelPolicy',
#        'ConvenienceFee', 'ConvenienceFeeType', 'ConvenienceFeeTotal',
#        'AffiliateId', 'RoomCombination', 'RoomChain', 'Latitude', 'Longitude',
#        'Rating', 'Floors', 'Alias', 'Punchline', 'MapURL', 'VideoURL',
#        'PromoTitle', 'PromoDetail', 'Distances', 'AdditionalInfo', 'Awards',
#        'Events', 'OtherFees', 'Facebook', 'Twitter', 'Linkedin'],
#       dtype='object')

# %%
x=(df.StarRating).astype(float)

# %%
StarRating= df[x == 5 ]
StarRating.head()
# Out:
#       HotelId                   HotelName CategoryList PropertyType  IsPrime  \
# 4   H!0282309        Park Hyatt Hyderabad         None         None    False
# 6   H!0077709                 Taj Krishna         None         None    False
# 9   H!0101661                 Taj Banjara         None         None    False
# 10  H!0369986  Hyatt Hyderabad Gachibowli         None         None    False
# 12  H!0077708                  Taj Deccan         None         None    False
#
#                                           Description HotelChain StarRating  \
# 4   Centrally located in the heart of upscale Banj...                     5
# 6   The Taj Krishna Hotel is placed in the capital...                     5
# 9   Property Location A stay at Taj Banjara places...                     5
# 10  Hyatt Hyderabad Gachibowli is located in the b...                     5
# 12  Sprawling across the Banjara Hills, Taj Deccan...                     5
#
# ...

# %%
json=StarRating.to_json(r'Desktop//hydrabad_starrating.json')
