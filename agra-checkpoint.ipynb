# %%
import numpy as np
import pandas as pd
import itertools
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
from pandas.io.json import json_normalize
import json

# %%
with open("C:/Users/akhan.extern/Desktop/jsondata/google.json") as json_data:
    sample_object = json.load(json_data)

df = pd.io.json.json_normalize(sample_object)
df.columns = df.columns.map(lambda x: x.split(".")[-1])

print(df.shape)
# Out:
# (20, 21)

# %%
df.columns
# Out:
# Index(['icon', 'id', 'name', 'photos', 'place_id', 'reference', 'scope',
#        'types', 'vicinity', 'lat', 'lng', 'lat', 'lng', 'lat', 'lng', 'rating',
#        'user_ratings_total', 'open_now', 'compound_code', 'global_code',
#        'price_level'],
#       dtype='object')

# %%
df.name
# Out:
# 0                                                Mumbai
# 1     Courtyard by Marriott Mumbai International Air...
# 2                                  Kohinoor Continental
# 3                       Dragonfly Hotel - The Art Hotel
# 4                                       Hotel Residency
# 5                                       Hotel Le Grande
# 6                 Highway Residency andheri East Mumbai
# 7                                           The Mirador
# 8                            The International by Tunga
# 9                                           Just Kerala
# 10                                     THE ONTIME HOTEL
# 11                            iStay Hotels MIDC Andheri
# 12                                   DTDC International
# 13                                 HOTEL JYOTI DWELLING
# 14                                   Velocity Car World
# 15                                                 MCPL
# 16                              Vaishno Devi Industries
# 17                                       Ace Industries
# 18                                      Prime Dormitory
# 19                                         Andheri East
# Name: name, dtype: object

# %%
with open('C:/Users/akhan.extern/Desktop/jsondata/zomat.json') as json_data:
    sample_object = json.load(json_data)

data = pd.io.json.json_normalize(sample_object)
data.columns = data.columns.map(lambda x: x.split(".")[-1])

print(data.shape)
# Out:
# (5, 63)

# %%
data.columns
# Out:
# Index(['delivery', 'takeaway', 'res_id', 'apikey', 'id', 'name', 'url',
#        'address', 'locality', 'city', 'city_id', 'latitude', 'longitude',
#        'zipcode', 'country_id', 'locality_verbose', 'switch_to_order_menu',
#        'cuisines', 'timings', 'average_cost_for_two', 'price_range',
#        'currency', 'highlights', 'offers', 'opentable_support',
#        'is_zomato_book_res', 'mezzo_provider', 'is_book_form_web_view',
#        'book_form_web_view_url', 'book_again_url', 'thumb', 'aggregate_rating',
#        'rating_text', 'rating_color', 'text', 'type', 'tint', 'votes',
#        'custom_rating_text', 'custom_rating_text_background',
#        'rating_tool_tip', 'all_reviews_count', 'photos_url', 'photo_count',
#        'menu_url', 'featured_image', 'has_online_delivery',
#        'is_delivering_now', 'include_bogo_offers', 'deeplink',
#        'is_table_reservation_supported', 'has_table_booking', 'events_url',
#        'phone_numbers', 'reviews', 'establishment', 'establishment_types',
#        'photos', 'medio_provider', 'order_url', 'order_deeplink', 'book_url',
#        'zomato_events'],
#       dtype='object')

# %%
data.name
# Out:
# 0             Biryani Burp
# 1    The Punjabi's Kitchen
# 2     Mumma's Rolls & More
# 3                    Zesto
# 4     Amore Gourmet Gelato
# Name: name, dtype: object

# %%
x=set(df['name']).intersection(set(data['name']))

# %%
x
# Out:
# set()

# %%
set(df.columns).intersection(set(data.columns))
# Out:
# {'id', 'name', 'photos'}

# %%
with open('C:/Users/akhan.extern/Desktop/jsondata/etravos.json') as json_data:
    sample_object = json.load(json_data)

data = pd.io.json.json_normalize(sample_object)
data.columns = data.columns.map(lambda x: x.split(".")[-1])

print(data.shape)
# Out:
# (23, 58)

# %%
data.columns
# Out:
# Index(['HotelId', 'HotelName', 'CategoryList', 'PropertyType', 'IsPrime',
#        'Description', 'HotelChain', 'StarRating', 'Rooms', 'MinRate', 'RPH',
#        'WebService', 'HotelAddress', 'PostalCode', 'City', 'LocationInfo',
#        'PhoneNumber', 'Fax', 'Email', 'Website', 'Checkintime', 'Checkouttime',
#        'CreditCards', 'HotelServices', 'RoomServices', 'Facilities',
#        'CountryCode', 'AirportCode', 'SupplierType', 'PropertyCategory',
#        'Provider', 'RoomDetails', 'HotelImages', 'HotelPolicy',
#        'ConvenienceFee', 'ConvenienceFeeType', 'ConvenienceFeeTotal',
#        'AffiliateId', 'RoomCombination', 'RoomChain', 'Latitude', 'Longitude',
#        'Rating', 'Floors', 'Alias', 'Punchline', 'MapURL', 'VideoURL',
#        'PromoTitle', 'PromoDetail', 'Distances', 'AdditionalInfo', 'Awards',
#        'Events', 'OtherFees', 'Facebook', 'Twitter', 'Linkedin'],
#       dtype='object')

# %%
x=(data.StarRating).astype(float)
x
# Out:
# 0     2.0
# 1     3.0
# 2     0.0
# 3     3.0
# 4     3.0
# 5     3.0
# 6     3.0
# 7     3.0
# 8     3.0
# 9     4.0
# 10    4.0
# 11    4.0
# 12    5.0
# 13    4.0
# 14    3.0
# 15    3.0
# 16    5.0
# 17    5.0
# 18    5.0
# 19    5.0
# 20    5.0
# 21    5.0
# 22    5.0
# Name: StarRating, dtype: float64

# %%
StarRating= data[x == 5 ]
StarRating.head()
# Out:
#       HotelId                        HotelName CategoryList PropertyType  \
# 12  H!0062675                    Clarks Shiraz         None         None
# 16  H!0413011          Courtyard Marriott Agra         None         None
# 17  H!0047568  The Gateway Fatehabad Road Agra         None         None
# 18  H!0047572                       ITC Mughal         None         None
# 19  H!0047573                     Trident Agra         None         None
#
#     IsPrime                                        Description HotelChain  \
# 12    False  Property Location With a stay at Hotel Clarks ...
# 16    False  This property is situated in Agra . Guests may...
# 17    False  Offering guests a view of the Taj Mahal from i...
# 18    False  Sprawled over 14 hectares of luxurious gardens...
# 19    False  This 5 star hotel is located within the city o...
#
#    StarRating  Rooms  MinRate  ... PromoTitle PromoDetail Distances  \
# 12          5      0        0  ...       None        None      None
# 16          5      0        0  ...       None        None      None
# 17          5      0        0  ...       None        None      None
# 18          5      0        0  ...       None        None      None
# 19          5      0        0  ...       None        None      None
#
#    AdditionalInfo Awards Events OtherFees Facebook Twitter Linkedin
# 12                  None   None      None             None
# 16                  None   None      None             None
# 17                  None   None      None             None
# 18                  None   None      None             None
# 19                  None   None      None             None
#
# [5 rows x 58 columns]

# %%
StarRating.HotelImages
# Out:
# 12    [{'Imagedesc': 'Hotel Images', 'Imagepath': 'h...
# 16    [{'Imagedesc': 'Hotel Images', 'Imagepath': 'h...
# 17    [{'Imagedesc': 'Hotel Images', 'Imagepath': 'h...
# 18    [{'Imagedesc': 'Hotel Images', 'Imagepath': 'h...
# 19    [{'Imagedesc': 'Hotel Images', 'Imagepath': 'h...
# 20    [{'Imagedesc': 'Hotel Images', 'Imagepath': 'h...
# 21    [{'Imagedesc': 'Hotel Images', 'Imagepath': 'h...
# 22    [{'Imagedesc': 'Hotel Images', 'Imagepath': 'h...
# Name: HotelImages, dtype: object

# %%
json=StarRating.to_json(r'Desktop//StarRating.json')

# %%
with open('C:/Users/akhan.extern/Desktop/jsondata/googlehotel.json') as json_data:
    sample_object = json.load(json_data)

df = pd.io.json.json_normalize(sample_object)
df.columns = df.columns.map(lambda x: x.split(".")[-1])

print(df.shape)
# Out:
# (20, 19)

# %%
df.columns
# Out:
# Index(['icon', 'id', 'name', 'photos', 'place_id', 'reference', 'scope',
#        'types', 'vicinity', 'lat', 'lng', 'lat', 'lng', 'lat', 'lng', 'rating',
#        'user_ratings_total', 'open_now', 'compound_code', 'global_code',
#        'price_level'],
#       dtype='object')

# %%
df.name
# Out:
# 0                                                Mumbai
# 1     Courtyard by Marriott Mumbai International Air...
# 2                                  Kohinoor Continental
# 3                       Dragonfly Hotel - The Art Hotel
# 4                                       Hotel Residency
# 5                                       Hotel Le Grande
# 6                 Highway Residency andheri East Mumbai
# 7                                           The Mirador
# 8                            The International by Tunga
# 9                                           Just Kerala
# 10                                     THE ONTIME HOTEL
# 11                            iStay Hotels MIDC Andheri
# 12                                   DTDC International
# 13                                 HOTEL JYOTI DWELLING
# 14                                   Velocity Car World
# 15                                                 MCPL
# 16                              Vaishno Devi Industries
# 17                                       Ace Industries
# 18                                      Prime Dormitory
# 19                                         Andheri East
# Name: name, dtype: object

# %%
data.HotelName
# Out:
# 0                  Optimum Tara Palace
# 1                        Taj Inn Hotel
# 2                     Treebo Rigel Inn
# 3                        Hotel Riviera
# 4     Usha Kiran Palace Hotel & Towers
# 5                          The Retreat
# 6                    Hotel Taj Resorts
# 7                    Hotel Karan Vilas
# 8                    Seven Hills Tower
# 9                          Marina Agra
# 10           Doubletree By Hilton Agra
# 11                  The Grand Imperial
# 12                       Clarks Shiraz
# 13                     Mansingh Palace
# 14                   Hotel Atulyaa Taj
# 15              Bhawna Clarks Inn Agra
# 16             Courtyard Marriott Agra
# 17     The Gateway Fatehabad Road Agra
# 18                          ITC Mughal
# 19                        Trident Agra
# 20                       Jaypee Palace
# 21     Radisson Blu Agra Taj East Gate
# 22                The Oberoi Amarvilas
# Name: HotelName, dtype: object

# %%
data.HotelAddress
# Out:
# 0             Ship Gram Taj Mahal East Gate 281001 Agra
# 1     18/163 B/4 Taj View X-ing Fatehabad Road Fateh...
# 2     Shamshabad Road Gol Market Rajpur Chungi Agra ...
# 3     Plot 18E Fatehabad Road Taj Nagri Phase-1, Beh...
# 4     Pratappura Crossing M.G. Road Agra 282 001  M....
# 5     Taj Nagari Phase -1 Near Prateek Enclave Shilp...
# 6     Plot No.538 Near Shilp Gram, Taj Mahal Estern ...
# 7     Fatehabad Road opposite Hotel Jaypee Palace Ag...
# 8     Fatehabad Road Jasoriya Enclave Opposite AXIS ...
# 9     16/2/8, Commercial Complex Sanjay Place M.G. R...
# 10             B/H - 1&2 Taj Nagri Phase II Agra 282001
# 11      M.G. Road Agra Uttar Pradesh 282 001  M.G. Road
# 12                  54 Taj Road Agra 282 001   Taj Road
# 13         Fatehabad Road Agra 282 001   Fatehabad Road
# 14    538, Near Shilp Gram Taj Mahal (Eastern Gate) ...
# 15    Bhawna Tower Kailashouri Crossing Sector 16B A...
# 16                  Taj Nagri, Phase II, Fatehabad Road
# 17    Taj Ganj Fatehabad Road Agra 282 001 Uttar Pra...
# 18        Taj Ganj Agra 282 001 Uttar Pradesh  Taj Ganj
# 19          Fatehabad Road Agra 282001   Fatehabad Road
# 20    Fatehabad Road Agra 282 003 Uttar Pradesh  Fat...
# 21                            Uttar Pradesh 282001 Agra
# 22    Taj East Gate Road Agra 282 001 Uttar Pradesh ...
# Name: HotelAddress, dtype: object

# %%
rating=df.rating

# %%
StarRating=(round(rating))
StarRating
# Out:
# 0     NaN
# 1     4.0
# 2     4.0
# 3     4.0
# 4     4.0
# 5     4.0
# 6     4.0
# 7     4.0
# 8     4.0
# 9     4.0
# 10    4.0
# 11    4.0
# 12    4.0
# 13    4.0
# 14    4.0
# 15    5.0
# 16    5.0
# 17    NaN
# 18    2.0
# 19    NaN
# Name: rating, dtype: float64

# %%
StarRating= df[StarRating == 4 ]
StarRating
# Out:
#                                     formatted_address  \
# 0   C-1, C-2, Fatehabad Rd, Taj Nagari Phase 1, R....
# 1   Ii, Fatehabad Rd, Taj Nagri Phase 2, Tajganj, ...
# 2   Fatehabad Rd, Opp. Hotel Trident, Taj Nagari P...
# 3   Fatehabad Rd, Near KFC Agra, Tajganj, Agra, Ut...
# 4   54, Taj Rd, phol syed crossing Tajganj, Agra C...
# 5   163A, 18, 6, Shamshabad Road, Vibhav Nagar, Ag...
# 6   2/95 Taj West Gate Road, Tajganj, Agra, Uttar ...
# 7   Opp. Hotel Jaypee Palace, Fatehabad Rd, Agra, ...
# 8   Taj, Fatehabad Rd, Taj Nagri Phase 2, Raj Naga...
# 9   A-15, Fatehabad Rd, Taj Nagri Phase 2, Tajganj...
# 10  Itc Mughal, Fatehabad Rd, Tajganj, Agra, Uttar...
# 11  Mahatma Gandhi Rd, Pratap Pura, Civil Lines, A...
# 12  Taj Nagri 1 Shilpgram, MIG, Phase 1, MIG Colon...
# 13  33/110, Mahatma Gandhi Road, Pratappura, Mahat...
# 14  1076/2, Fatehabad Rd, Opposite Hotel ITC Mugha...
# 15  Plot No, 7, Fatehabad Rd, Taj Nagri Phase 2, K...
# 16  768, Taj Nagari Phase 1, Naharganj, Tajganj, N...
# 18  Fatehabad Rd, Nai basti, Rakabganj, Agra, Utta...
# 19  Plot No.-94 100-Feet Road, Fatehabad Rd, oppos...
#
#                                                  icon  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                           id  \
# 0   dc8cb23558dc4e72decd40d31f320757a9e04b59
# 1   b006d5fe66e2829ac45cae7e07ad15da90e8c148
# 2   f9d5162164224afe4101ce5cd338f7b0142dfe15
# 3   8006ca03c98ed6d561c54cd833d43f9d7221ca0e
# 4   9e0eeca784262edc7847a31e4e21326227598a8d
# 5   df0660b240c8417bd14e5d7fe554ed211a1b4136
# 6   0bffcaceba16069c979ffdc8a140b2bd19754a14
# 7   12a091f7a89ab83db79a965919ae35f111f94803
# 8   c765bb248ad8af7635fb91609930a27e0d8d261b
# 9   08691b62fc102e05accbceaa8daf4e24fa1d6369
# 10  12989040fe09f103bd26a58ca6a1236c7c159192
# 11  f8a7d2d7e1393dba881f825143849babf2f580e0
# 12  8c1906a5fa8834d01c5c5b11788bc04a3e29e2f4
# 13  525744da6ad702841434f12886b9eeb2dd5e2220
# 14  4247e1a198adf82903d0eaec41c6791da2ba5c49
# 15  eba4f80020e148d2547ac55b5cf2be544b6cc6d9
# 16  f3e2578507952c5160d7dd5532841d6acbcf1353
# 18  e92070df624a791865eb454ab13492fb2659c4ee
# 19  95a0ad5f9735328e72cecf5ff229f8d1f3ab0afe
#
#                                            name  \
# 0                           Radisson Hotel Agra
# 1                    Courtyard by Marriott Agra
# 2                           Hotel The Taj Vilas
# 3                Crystal Sarovar Premiere, Agra
# 4                     Hotel Clarks Shiraz, Agra
# 5              Purplebeds by VITS - Dasaprakash
# 6                               Hotel Sidhartha
# 7                          Hotel Royale' Regent
# 8                              Hotel Pearl Blue
# 9                Hotel Maple Grand & Restaurant
# 10  ITC Mughal, A Luxury Collection Hotel, Agra
# 11                    Usha Kiran Hotel & Towers
# 12                               Moustache Agra
# 13                                 Hotel Orange
# 14                                Hotel Samovar
# 15                            Hotel Light House
# 16                         Hotel Crimson palace
# 18                      Howard Plaza - The Fern
# 19                     Hotel Aaradhya Residency
#
#                                                photos  \
# 0   [{'height': 5357, 'html_attributions': ['<a hr...
# 1   [{'height': 1366, 'html_attributions': ['<a hr...
# 2   [{'height': 500, 'html_attributions': ['<a hre...
# 3   [{'height': 2322, 'html_attributions': ['<a hr...
# 4   [{'height': 350, 'html_attributions': ['<a hre...
# 5   [{'height': 4608, 'html_attributions': ['<a hr...
# 6   [{'height': 2160, 'html_attributions': ['<a hr...
# 7   [{'height': 3120, 'html_attributions': ['<a hr...
# 8   [{'height': 428, 'html_attributions': ['<a hre...
# 9   [{'height': 3840, 'html_attributions': ['<a hr...
# 10  [{'height': 682, 'html_attributions': ['<a hre...
# 11  [{'height': 1440, 'html_attributions': ['<a hr...
# 12  [{'height': 4032, 'html_attributions': ['<a hr...
# 13  [{'height': 1024, 'html_attributions': ['<a hr...
# 14  [{'height': 1383, 'html_attributions': ['<a hr...
# 15  [{'height': 3840, 'html_attributions': ['<a hr...
# 16  [{'height': 2268, 'html_attributions': ['<a hr...
# 18  [{'height': 1367, 'html_attributions': ['<a hr...
# 19  [{'height': 3024, 'html_attributions': ['<a hr...
#
#                        place_id  rating                    reference  \
# 0   ChIJUxFmmA9xdDkR3DpaV2nlAi4     4.3  ChIJUxFmmA9xdDkR3DpaV2nlAi4
# 1   ChIJt2hNYAtxdDkRo1y24D0neYQ     4.4  ChIJt2hNYAtxdDkRo1y24D0neYQ
# 2   ChIJUffaiihxdDkR-CX_MWL0-ts     4.1  ChIJUffaiihxdDkR-CX_MWL0-ts
# 3   ChIJCQP0rhNxdDkRSN9GFlLZ3FQ     4.3  ChIJCQP0rhNxdDkRSN9GFlLZ3FQ
# 4   ChIJTSS64DNxdDkRCXIdGhtlc2M     4.3  ChIJTSS64DNxdDkRCXIdGhtlc2M
# 5   ChIJp9qXfTlxdDkRAsozoPqVabg     3.8  ChIJp9qXfTlxdDkRAsozoPqVabg
# 6   ChIJMXpigyFxdDkRL6Ik_anr7l4     3.9  ChIJMXpigyFxdDkRL6Ik_anr7l4
# 7   ChIJC54hWIRxdDkR08NwBwNbGDE     4.2  ChIJC54hWIRxdDkR08NwBwNbGDE
# 8   ChIJU1UF3wpxdDkR8Tdtd6U0Ss8     3.6  ChIJU1UF3wpxdDkR8Tdtd6U0Ss8
# 9   ChIJtwPaFhNxdDkRQTvxtLbKuAQ     4.1  ChIJtwPaFhNxdDkRQTvxtLbKuAQ
# 10  ChIJiS-v2t_8DDkRfNgu7g5TpUQ     4.5  ChIJiS-v2t_8DDkRfNgu7g5TpUQ
# 11  ChIJyd6qutB2dDkRZzysIn90Oy4     3.6  ChIJyd6qutB2dDkRZzysIn90Oy4
# 12  ChIJRbIu3g9xdDkRAsxxN9O2CXE     3.9  ChIJRbIu3g9xdDkRAsxxN9O2CXE
# 13  ChIJdcs3ubJ2dDkRK94NfY59hsE     3.9  ChIJdcs3ubJ2dDkRK94NfY59hsE
# 14  ChIJdxJhDhZxdDkR23DK1rVHJ6s     3.6  ChIJdxJhDhZxdDkR23DK1rVHJ6s
# 15  ChIJ7wOj_HRxdDkR2-a5Z6yldRE     4.0  ChIJ7wOj_HRxdDkR2-a5Z6yldRE
# 16  ChIJe01IdhZxdDkRwUxqw_UZSpo     3.8  ChIJe01IdhZxdDkRwUxqw_UZSpo
# 18  ChIJXVI_VflxdDkRXPd1Nfmoxgc     4.2  ChIJXVI_VflxdDkRXPd1Nfmoxgc
# 19  ChIJiyXXVG1xdDkRluGpZeg6K3I     4.0  ChIJiyXXVG1xdDkRluGpZeg6K3I
#
#                                                 types  user_ratings_total  \
# 0         [lodging, point_of_interest, establishment]                8299
# 1         [lodging, point_of_interest, establishment]                3946
# 2         [lodging, point_of_interest, establishment]                1754
# 3         [lodging, point_of_interest, establishment]                3703
# 4         [lodging, point_of_interest, establishment]                3884
# 5   [lodging, restaurant, food, point_of_interest,...                 635
# 6         [lodging, point_of_interest, establishment]                 486
# 7         [lodging, point_of_interest, establishment]                 342
# 8         [lodging, point_of_interest, establishment]                 575
# 9         [lodging, point_of_interest, establishment]                 487
# 10        [lodging, point_of_interest, establishment]                4709
# 11        [lodging, point_of_interest, establishment]                 456
# 12        [lodging, point_of_interest, establishment]                 411
# 13  [lodging, restaurant, food, point_of_interest,...                 436
# 14  [lodging, restaurant, food, point_of_interest,...                 358
# 15        [lodging, point_of_interest, establishment]                 734
# 16        [lodging, point_of_interest, establishment]                 574
# 18        [lodging, point_of_interest, establishment]                  96
# 19        [lodging, point_of_interest, establishment]                 131
#
#           lat        lng        lat        lng        lat        lng open_now  \
# 0   27.158642  78.053556  27.160022  78.054806  27.157322  78.052106     True
# 1   27.156381  78.059524  27.157806  78.060622  27.155107  78.057923     True
# 2   27.157999  78.059058  27.159501  78.060505  27.156801  78.057805      NaN
# 3   27.157261  78.050842  27.158861  78.052186  27.156162  78.049486      NaN
# 4   27.158770  78.024971  27.160122  78.026311  27.157423  78.023611     True
# 5   27.158295  78.034290  27.159640  78.035609  27.156940  78.032909     True
# 6   27.169388  78.040624  27.170736  78.041925  27.168037  78.039225      NaN
# 7   27.152793  78.069339  27.154259  78.070809  27.151559  78.068109     True
# 8   27.156165  78.062312  27.157465  78.063736  27.154765  78.061037     True
# 9   27.155698  78.050056  27.157051  78.051344  27.154352  78.048644     True
# 10  27.160802  78.044126  27.161917  78.045442  27.159217  78.042742     True
# 11  27.201420  78.003960  27.202745  78.005370  27.200046  78.002670     True
# 12  27.163867  78.053754  27.165216  78.055104  27.162516  78.052405     True
# 13  27.167869  78.008713  27.169205  78.010149  27.166506  78.007450     True
# 14  27.159612  78.043071  27.161051  78.044481  27.158351  78.041782    False
# 15  27.152723  78.062043  27.154131  78.063326  27.151431  78.060626     True
# 16  27.162190  78.054552  27.163463  78.055881  27.160763  78.053181     True
# 18  27.162880  78.036651  27.164181  78.037909  27.161482  78.035209     True
# 19  27.154162  78.053519  27.155534  78.054839  27.152835  78.052140     True
#
#                              compound_code  global_code
# 0     5353+FC Tajganj, Agra, Uttar Pradesh  7JVW5353+FC
# 1              5345+HR Agra, Uttar Pradesh  7JVW5345+HR
# 2              5355+5J Agra, Uttar Pradesh  7JVW5355+5J
# 3     5342+W8 Tajganj, Agra, Uttar Pradesh  7JVW5342+W8
# 4     525F+GX Tajganj, Agra, Uttar Pradesh  7JVW525F+GX
# 5              525M+8P Agra, Uttar Pradesh  7JVW525M+8P
# 6              529R+Q6 Agra, Uttar Pradesh  7JVW529R+Q6
# 7              5339+4P Agra, Uttar Pradesh  7JVW5339+4P
# 8              5346+FW Agra, Uttar Pradesh  7JVW5346+FW
# 9     5342+72 Tajganj, Agra, Uttar Pradesh  7JVW5342+72
# 10    526V+8M Tajganj, Agra, Uttar Pradesh  7JVW526V+8M
# 11             6223+HH Agra, Uttar Pradesh  7JVW6223+HH
# 12             5373+GG Agra, Uttar Pradesh  7JVW5373+GG
# 13  5295+4F Rakabganj, Agra, Uttar Pradesh  7JVW5295+4F
# 14    525V+R6 Tajganj, Agra, Uttar Pradesh  7JVW525V+R6
# 15             5336+3R Agra, Uttar Pradesh  7JVW5336+3R
# 16    5363+VR Tajganj, Agra, Uttar Pradesh  7JVW5363+VR
# 18  527P+5M Rakabganj, Agra, Uttar Pradesh  7JVW527P+5M
# 19    5333+MC Tajganj, Agra, Uttar Pradesh  7JVW5333+MC

# %%
x=set(data['HotelName']).intersection(set(df['name']))

# %%
x
# Out:
# set()

# %%
finaldata=(pd.concat([data,df],axis=1))
finaldata
# Out:
#       HotelId                         HotelName CategoryList PropertyType  \
# 0   H!0280340               Optimum Tara Palace         None         None
# 1   H!0393001                     Taj Inn Hotel         None         None
# 2   H!0449549                  Treebo Rigel Inn         None         None
# 3   H!0539259                     Hotel Riviera         None         None
# 4   H!0295629  Usha Kiran Palace Hotel & Towers         None         None
# 5   H!0280341                       The Retreat         None         None
# 6   H!0280321                 Hotel Taj Resorts         None         None
# 7   H!0415489                 Hotel Karan Vilas         None         None
# 8   H!0462437                 Seven Hills Tower         None         None
# 9   H!0062676                       Marina Agra         None         None
# 10  H!0368861         Doubletree By Hilton Agra         None         None
# 11  H!0079211                The Grand Imperial         None         None
# 12  H!0062675                     Clarks Shiraz         None         None
# 13  H!0062677                   Mansingh Palace         None         None
# 14  H!0454839                 Hotel Atulyaa Taj         None         None
# 15  H!0415457            Bhawna Clarks Inn Agra         None         None
# 16  H!0413011           Courtyard Marriott Agra         None         None
# 17  H!0047568   The Gateway Fatehabad Road Agra         None         None
# 18  H!0047572                        ITC Mughal         None         None
# 19  H!0047573                      Trident Agra         None         None
# 20  H!0047571                     Jaypee Palace         None         None
# 21  H!0247736   Radisson Blu Agra Taj East Gate         None         None
# 22  H!0048160              The Oberoi Amarvilas         None         None
#
#     IsPrime                                        Description HotelChain  \
# 0     False  Property Location With a stay at Optimum Tara ...
# 1     False  Property Location With a stay at Hotel Taj Inn...
# 2     False  Property Location With a stay at The Rigel in ...
# 3     False  Property Location With a stay at Hotel Riviera...
# 4     False  Property Location With a stay at Usha Kiran Pa...
# 5     False  Property Location With a stay at The Retreat i...
# 6     False  Property Location When you stay at Hotel Taj R...
# 7     False  Property Location With a stay at Hotel Karan V...
# 8     False  Property Location With a stay at Hotel Seven H...
# 9     False  Property Location A stay at Hotel Marina Agra ...
# 10    False  Boasting stunning views of the Taj Mahal, just...
# 11    False  The hotel is located in the heart of the city,...
# 12    False  Property Location With a stay at Hotel Clarks ...
# 13    False  The hotel overlooks the man-made Ana Sagar Lak...
# 14    False  Property Location With a stay at Hotel Atulyaa...
# 15    False  Property Location With a stay at Bhawna Clarks...
# 16    False  This property is situated in Agra . Guests may...
# 17    False  Offering guests a view of the Taj Mahal from i...
# 18    False  Sprawled over 14 hectares of luxurious gardens...
# 19    False  This 5 star hotel is located within the city o...
# 20    False  Set amidst 25 acres of lush landscaped gardens...
# 21    False  Nestled within its private 4.5 acres of land i...
# 22    False  This 5 star hotel is located within the city o...
#
#    StarRating  Rooms  MinRate  ...                     place_id rating  \
# 0           2      0        0  ...  ChIJUxFmmA9xdDkR3DpaV2nlAi4    4.3
# 1           3      0        0  ...  ChIJt2hNYAtxdDkRo1y24D0neYQ    4.4
# 2           0      0        0  ...  ChIJUffaiihxdDkR-CX_MWL0-ts    4.1
# 3           3      0        0  ...  ChIJCQP0rhNxdDkRSN9GFlLZ3FQ    4.3
# 4           3      0        0  ...  ChIJTSS64DNxdDkRCXIdGhtlc2M    4.3
# 5           3      0        0  ...  ChIJp9qXfTlxdDkRAsozoPqVabg    3.8
# 6           3      0        0  ...  ChIJMXpigyFxdDkRL6Ik_anr7l4    3.9
# 7           3      0        0  ...  ChIJC54hWIRxdDkR08NwBwNbGDE    4.2
# 8           3      0        0  ...  ChIJU1UF3wpxdDkR8Tdtd6U0Ss8    3.6
# 9           4      0        0  ...  ChIJtwPaFhNxdDkRQTvxtLbKuAQ    4.1
# 10          4      0        0  ...  ChIJiS-v2t_8DDkRfNgu7g5TpUQ    4.5
# 11          4      0        0  ...  ChIJyd6qutB2dDkRZzysIn90Oy4    3.6
# 12          5      0        0  ...  ChIJRbIu3g9xdDkRAsxxN9O2CXE    3.9
# 13          4      0        0  ...  ChIJdcs3ubJ2dDkRK94NfY59hsE    3.9
# 14          3      0        0  ...  ChIJdxJhDhZxdDkR23DK1rVHJ6s    3.6
# 15          3      0        0  ...  ChIJ7wOj_HRxdDkR2-a5Z6yldRE    4.0
# 16          5      0        0  ...  ChIJe01IdhZxdDkRwUxqw_UZSpo    3.8
# 17          5      0        0  ...  ChIJye4YLh9xdDkRFcEwjjsQ7f4    3.4
# 18          5      0        0  ...  ChIJXVI_VflxdDkRXPd1Nfmoxgc    4.2
# 19          5      0        0  ...  ChIJiyXXVG1xdDkRluGpZeg6K3I    4.0
# 20          5      0        0  ...                          NaN    NaN
# 21          5      0        0  ...                          NaN    NaN
# 22          5      0        0  ...                          NaN    NaN
#
#                       reference  \
# 0   ChIJUxFmmA9xdDkR3DpaV2nlAi4
# 1   ChIJt2hNYAtxdDkRo1y24D0neYQ
# 2   ChIJUffaiihxdDkR-CX_MWL0-ts
# 3   ChIJCQP0rhNxdDkRSN9GFlLZ3FQ
# 4   ChIJTSS64DNxdDkRCXIdGhtlc2M
# 5   ChIJp9qXfTlxdDkRAsozoPqVabg
# 6   ChIJMXpigyFxdDkRL6Ik_anr7l4
# 7   ChIJC54hWIRxdDkR08NwBwNbGDE
# 8   ChIJU1UF3wpxdDkR8Tdtd6U0Ss8
# 9   ChIJtwPaFhNxdDkRQTvxtLbKuAQ
# 10  ChIJiS-v2t_8DDkRfNgu7g5TpUQ
# 11  ChIJyd6qutB2dDkRZzysIn90Oy4
# 12  ChIJRbIu3g9xdDkRAsxxN9O2CXE
# 13  ChIJdcs3ubJ2dDkRK94NfY59hsE
# 14  ChIJdxJhDhZxdDkR23DK1rVHJ6s
# 15  ChIJ7wOj_HRxdDkR2-a5Z6yldRE
# 16  ChIJe01IdhZxdDkRwUxqw_UZSpo
# 17  ChIJye4YLh9xdDkRFcEwjjsQ7f4
# 18  ChIJXVI_VflxdDkRXPd1Nfmoxgc
# 19  ChIJiyXXVG1xdDkRluGpZeg6K3I
# 20                          NaN
# 21                          NaN
# 22                          NaN
#
#                                                 types user_ratings_total  \
# 0         [lodging, point_of_interest, establishment]             8299.0
# 1         [lodging, point_of_interest, establishment]             3946.0
# 2         [lodging, point_of_interest, establishment]             1754.0
# 3         [lodging, point_of_interest, establishment]             3703.0
# 4         [lodging, point_of_interest, establishment]             3884.0
# 5   [lodging, restaurant, food, point_of_interest,...              635.0
# 6         [lodging, point_of_interest, establishment]              486.0
# 7         [lodging, point_of_interest, establishment]              342.0
# 8         [lodging, point_of_interest, establishment]              575.0
# 9         [lodging, point_of_interest, establishment]              487.0
# 10        [lodging, point_of_interest, establishment]             4709.0
# 11        [lodging, point_of_interest, establishment]              456.0
# 12        [lodging, point_of_interest, establishment]              411.0
# 13  [lodging, restaurant, food, point_of_interest,...              436.0
# 14  [lodging, restaurant, food, point_of_interest,...              358.0
# 15        [lodging, point_of_interest, establishment]              734.0
# 16        [lodging, point_of_interest, establishment]              574.0
# 17        [lodging, point_of_interest, establishment]              220.0
# 18        [lodging, point_of_interest, establishment]               96.0
# 19        [lodging, point_of_interest, establishment]              131.0
# 20                                                NaN                NaN
# 21                                                NaN                NaN
# 22                                                NaN                NaN
#
#           lat        lng open_now                           compound_code  \
# 0   27.158642  78.053556     True    5353+FC Tajganj, Agra, Uttar Pradesh
# 1   27.156381  78.059524     True             5345+HR Agra, Uttar Pradesh
# 2   27.157999  78.059058      NaN             5355+5J Agra, Uttar Pradesh
# 3   27.157261  78.050842      NaN    5342+W8 Tajganj, Agra, Uttar Pradesh
# 4   27.158770  78.024971     True    525F+GX Tajganj, Agra, Uttar Pradesh
# 5   27.158295  78.034290     True             525M+8P Agra, Uttar Pradesh
# 6   27.169388  78.040624      NaN             529R+Q6 Agra, Uttar Pradesh
# 7   27.152793  78.069339     True             5339+4P Agra, Uttar Pradesh
# 8   27.156165  78.062312     True             5346+FW Agra, Uttar Pradesh
# 9   27.155698  78.050056     True    5342+72 Tajganj, Agra, Uttar Pradesh
# 10  27.160802  78.044126     True    526V+8M Tajganj, Agra, Uttar Pradesh
# 11  27.201420  78.003960     True             6223+HH Agra, Uttar Pradesh
# 12  27.163867  78.053754     True             5373+GG Agra, Uttar Pradesh
# 13  27.167869  78.008713     True  5295+4F Rakabganj, Agra, Uttar Pradesh
# 14  27.159612  78.043071    False    525V+R6 Tajganj, Agra, Uttar Pradesh
# 15  27.152723  78.062043     True             5336+3R Agra, Uttar Pradesh
# 16  27.162190  78.054552     True    5363+VR Tajganj, Agra, Uttar Pradesh
# 17  27.170986  78.044578      NaN             52CV+9R Agra, Uttar Pradesh
# 18  27.162880  78.036651     True  527P+5M Rakabganj, Agra, Uttar Pradesh
# 19  27.154162  78.053519     True    5333+MC Tajganj, Agra, Uttar Pradesh
# 20        NaN        NaN      NaN                                     NaN
# 21        NaN        NaN      NaN                                     NaN
# 22        NaN        NaN      NaN                                     NaN
#
#     global_code
# 0   7JVW5353+FC
# 1   7JVW5345+HR
# 2   7JVW5355+5J
# 3   7JVW5342+W8
# 4   7JVW525F+GX
# 5   7JVW525M+8P
# 6   7JVW529R+Q6
# 7   7JVW5339+4P
# 8   7JVW5346+FW
# 9   7JVW5342+72
# 10  7JVW526V+8M
# 11  7JVW6223+HH
# 12  7JVW5373+GG
# 13  7JVW5295+4F
# 14  7JVW525V+R6
# 15  7JVW5336+3R
# 16  7JVW5363+VR
# 17  7JVW52CV+9R
# 18  7JVW527P+5M
# 19  7JVW5333+MC
# 20          NaN
# 21          NaN
# 22          NaN
#
# [23 rows x 169 columns]

# %%
fdata=(finaldata.columns.unique())
fdata
# Out:
# Index(['HotelId', 'HotelName', 'CategoryList', 'PropertyType', 'IsPrime',
#        'Description', 'HotelChain', 'StarRating', 'Rooms', 'MinRate', 'RPH',
#        'WebService', 'HotelAddress', 'PostalCode', 'City', 'LocationInfo',
#        'PhoneNumber', 'Fax', 'Email', 'Website', 'Checkintime', 'Checkouttime',
#        'CreditCards', 'HotelServices', 'RoomServices', 'Facilities',
#        'CountryCode', 'AirportCode', 'SupplierType', 'PropertyCategory',
#        'Provider', 'RoomDetails', 'HotelImages', 'HotelPolicy',
#        'ConvenienceFee', 'ConvenienceFeeType', 'ConvenienceFeeTotal',
#        'AffiliateId', 'RoomCombination', 'RoomChain', 'Latitude', 'Longitude',
#        'Rating', 'Floors', 'Alias', 'Punchline', 'MapURL', 'VideoURL',
#        'PromoTitle', 'PromoDetail', 'Distances', 'AdditionalInfo', 'Awards',
#        'Events', 'OtherFees', 'Facebook', 'Twitter', 'Linkedin',
#        'formatted_address', 'icon', 'id', 'name', 'photos', 'place_id',
#        'rating', 'reference', 'types', 'user_ratings_total', 'lat', 'lng',
#        'open_now', 'compound_code', 'global_code'],
#       dtype='object')

# %%
fdata=(finaldata[finaldata.columns.unique()])
fdata.name
# Out:
#                                            name  \
# 0                           Radisson Hotel Agra
# 1                    Courtyard by Marriott Agra
# 2                           Hotel The Taj Vilas
# 3                Crystal Sarovar Premiere, Agra
# 4                     Hotel Clarks Shiraz, Agra
# 5              Purplebeds by VITS - Dasaprakash
# 6                               Hotel Sidhartha
# 7                          Hotel Royale' Regent
# 8                              Hotel Pearl Blue
# 9                Hotel Maple Grand & Restaurant
# 10  ITC Mughal, A Luxury Collection Hotel, Agra
# 11                    Usha Kiran Hotel & Towers
# 12                               Moustache Agra
# 13                                 Hotel Orange
# 14                                Hotel Samovar
# 15                            Hotel Light House
# 16                         Hotel Crimson palace
# 17                                 Hotel Sheela
# 18                      Howard Plaza - The Fern
# 19                     Hotel Aaradhya Residency
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
#
#                                            name  \
# 0                           Radisson Hotel Agra
# 1                    Courtyard by Marriott Agra
# 2                           Hotel The Taj Vilas
# 3                Crystal Sarovar Premiere, Agra
# 4                     Hotel Clarks Shiraz, Agra
# 5              Purplebeds by VITS - Dasaprakash
# 6                               Hotel Sidhartha
# 7                          Hotel Royale' Regent
# 8                              Hotel Pearl Blue
# 9                Hotel Maple Grand & Restaurant
# 10  ITC Mughal, A Luxury Collection Hotel, Agra
# 11                    Usha Kiran Hotel & Towers
# 12                               Moustache Agra
# 13                                 Hotel Orange
# 14                                Hotel Samovar
# 15                            Hotel Light House
# 16                         Hotel Crimson palace
# 17                                 Hotel Sheela
# 18                      Howard Plaza - The Fern
# 19                     Hotel Aaradhya Residency
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
#
#                                            name
# 0                           Radisson Hotel Agra
# 1                    Courtyard by Marriott Agra
# 2                           Hotel The Taj Vilas
# 3                Crystal Sarovar Premiere, Agra
# 4                     Hotel Clarks Shiraz, Agra
# 5              Purplebeds by VITS - Dasaprakash
# 6                               Hotel Sidhartha
# 7                          Hotel Royale' Regent
# 8                              Hotel Pearl Blue
# 9                Hotel Maple Grand & Restaurant
# 10  ITC Mughal, A Luxury Collection Hotel, Agra
# 11                    Usha Kiran Hotel & Towers
# 12                               Moustache Agra
# 13                                 Hotel Orange
# 14                                Hotel Samovar
# 15                            Hotel Light House
# 16                         Hotel Crimson palace
# 17                                 Hotel Sheela
# 18                      Howard Plaza - The Fern
# 19                     Hotel Aaradhya Residency
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN

# %%
fdata.columns
# Out:
# Index(['HotelId', 'HotelId', 'HotelName', 'HotelName', 'CategoryList',
#        'CategoryList', 'PropertyType', 'PropertyType', 'IsPrime', 'IsPrime',
#        ...
#        'lng', 'open_now', 'open_now', 'open_now', 'compound_code',
#        'compound_code', 'compound_code', 'global_code', 'global_code',
#        'global_code'],
#       dtype='object', length=169)

# %%
finaldata['avg'] = finaldata[['StarRating', 'rating']].mean(axis=1)
finaldata
# Out:
#       HotelId                         HotelName CategoryList PropertyType  \
# 0   H!0280340               Optimum Tara Palace         None         None
# 1   H!0393001                     Taj Inn Hotel         None         None
# 2   H!0449549                  Treebo Rigel Inn         None         None
# 3   H!0539259                     Hotel Riviera         None         None
# 4   H!0295629  Usha Kiran Palace Hotel & Towers         None         None
# 5   H!0280341                       The Retreat         None         None
# 6   H!0280321                 Hotel Taj Resorts         None         None
# 7   H!0415489                 Hotel Karan Vilas         None         None
# 8   H!0462437                 Seven Hills Tower         None         None
# 9   H!0062676                       Marina Agra         None         None
# 10  H!0368861         Doubletree By Hilton Agra         None         None
# 11  H!0079211                The Grand Imperial         None         None
# 12  H!0062675                     Clarks Shiraz         None         None
# 13  H!0062677                   Mansingh Palace         None         None
# 14  H!0454839                 Hotel Atulyaa Taj         None         None
# 15  H!0415457            Bhawna Clarks Inn Agra         None         None
# 16  H!0413011           Courtyard Marriott Agra         None         None
# 17  H!0047568   The Gateway Fatehabad Road Agra         None         None
# 18  H!0047572                        ITC Mughal         None         None
# 19  H!0047573                      Trident Agra         None         None
# 20  H!0047571                     Jaypee Palace         None         None
# 21  H!0247736   Radisson Blu Agra Taj East Gate         None         None
# 22  H!0048160              The Oberoi Amarvilas         None         None
#
#     IsPrime                                        Description HotelChain  \
# 0     False  Property Location With a stay at Optimum Tara ...
# 1     False  Property Location With a stay at Hotel Taj Inn...
# 2     False  Property Location With a stay at The Rigel in ...
# 3     False  Property Location With a stay at Hotel Riviera...
# 4     False  Property Location With a stay at Usha Kiran Pa...
# 5     False  Property Location With a stay at The Retreat i...
# 6     False  Property Location When you stay at Hotel Taj R...
# 7     False  Property Location With a stay at Hotel Karan V...
# 8     False  Property Location With a stay at Hotel Seven H...
# 9     False  Property Location A stay at Hotel Marina Agra ...
# 10    False  Boasting stunning views of the Taj Mahal, just...
# 11    False  The hotel is located in the heart of the city,...
# 12    False  Property Location With a stay at Hotel Clarks ...
# 13    False  The hotel overlooks the man-made Ana Sagar Lak...
# 14    False  Property Location With a stay at Hotel Atulyaa...
# 15    False  Property Location With a stay at Bhawna Clarks...
# 16    False  This property is situated in Agra . Guests may...
# 17    False  Offering guests a view of the Taj Mahal from i...
# 18    False  Sprawled over 14 hectares of luxurious gardens...
# 19    False  This 5 star hotel is located within the city o...
# 20    False  Set amidst 25 acres of lush landscaped gardens...
# 21    False  Nestled within its private 4.5 acres of land i...
# 22    False  This 5 star hotel is located within the city o...
#
#    StarRating  Rooms  MinRate  ... rating                    reference  \
# 0           2      0        0  ...    4.3  ChIJUxFmmA9xdDkR3DpaV2nlAi4
# 1           3      0        0  ...    4.4  ChIJt2hNYAtxdDkRo1y24D0neYQ
# 2           0      0        0  ...    4.1  ChIJUffaiihxdDkR-CX_MWL0-ts
# 3           3      0        0  ...    4.3  ChIJCQP0rhNxdDkRSN9GFlLZ3FQ
# 4           3      0        0  ...    4.3  ChIJTSS64DNxdDkRCXIdGhtlc2M
# 5           3      0        0  ...    3.8  ChIJp9qXfTlxdDkRAsozoPqVabg
# 6           3      0        0  ...    3.9  ChIJMXpigyFxdDkRL6Ik_anr7l4
# 7           3      0        0  ...    4.2  ChIJC54hWIRxdDkR08NwBwNbGDE
# 8           3      0        0  ...    3.6  ChIJU1UF3wpxdDkR8Tdtd6U0Ss8
# 9           4      0        0  ...    4.1  ChIJtwPaFhNxdDkRQTvxtLbKuAQ
# 10          4      0        0  ...    4.5  ChIJiS-v2t_8DDkRfNgu7g5TpUQ
# 11          4      0        0  ...    3.6  ChIJyd6qutB2dDkRZzysIn90Oy4
# 12          5      0        0  ...    3.9  ChIJRbIu3g9xdDkRAsxxN9O2CXE
# 13          4      0        0  ...    3.9  ChIJdcs3ubJ2dDkRK94NfY59hsE
# 14          3      0        0  ...    3.6  ChIJdxJhDhZxdDkR23DK1rVHJ6s
# 15          3      0        0  ...    4.0  ChIJ7wOj_HRxdDkR2-a5Z6yldRE
# 16          5      0        0  ...    3.8  ChIJe01IdhZxdDkRwUxqw_UZSpo
# 17          5      0        0  ...    3.4  ChIJye4YLh9xdDkRFcEwjjsQ7f4
# 18          5      0        0  ...    4.2  ChIJXVI_VflxdDkRXPd1Nfmoxgc
# 19          5      0        0  ...    4.0  ChIJiyXXVG1xdDkRluGpZeg6K3I
# 20          5      0        0  ...    NaN                          NaN
# 21          5      0        0  ...    NaN                          NaN
# 22          5      0        0  ...    NaN                          NaN
#
#                                                 types user_ratings_total  \
# 0         [lodging, point_of_interest, establishment]             8299.0
# 1         [lodging, point_of_interest, establishment]             3946.0
# 2         [lodging, point_of_interest, establishment]             1754.0
# 3         [lodging, point_of_interest, establishment]             3703.0
# 4         [lodging, point_of_interest, establishment]             3884.0
# 5   [lodging, restaurant, food, point_of_interest,...              635.0
# 6         [lodging, point_of_interest, establishment]              486.0
# 7         [lodging, point_of_interest, establishment]              342.0
# 8         [lodging, point_of_interest, establishment]              575.0
# 9         [lodging, point_of_interest, establishment]              487.0
# 10        [lodging, point_of_interest, establishment]             4709.0
# 11        [lodging, point_of_interest, establishment]              456.0
# 12        [lodging, point_of_interest, establishment]              411.0
# 13  [lodging, restaurant, food, point_of_interest,...              436.0
# 14  [lodging, restaurant, food, point_of_interest,...              358.0
# 15        [lodging, point_of_interest, establishment]              734.0
# 16        [lodging, point_of_interest, establishment]              574.0
# 17        [lodging, point_of_interest, establishment]              220.0
# 18        [lodging, point_of_interest, establishment]               96.0
# 19        [lodging, point_of_interest, establishment]              131.0
# 20                                                NaN                NaN
# 21                                                NaN                NaN
# 22                                                NaN                NaN
#
#           lat        lng open_now                           compound_code  \
# 0   27.158642  78.053556     True    5353+FC Tajganj, Agra, Uttar Pradesh
# 1   27.156381  78.059524     True             5345+HR Agra, Uttar Pradesh
# 2   27.157999  78.059058      NaN             5355+5J Agra, Uttar Pradesh
# 3   27.157261  78.050842      NaN    5342+W8 Tajganj, Agra, Uttar Pradesh
# 4   27.158770  78.024971     True    525F+GX Tajganj, Agra, Uttar Pradesh
# 5   27.158295  78.034290     True             525M+8P Agra, Uttar Pradesh
# 6   27.169388  78.040624      NaN             529R+Q6 Agra, Uttar Pradesh
# 7   27.152793  78.069339     True             5339+4P Agra, Uttar Pradesh
# 8   27.156165  78.062312     True             5346+FW Agra, Uttar Pradesh
# 9   27.155698  78.050056     True    5342+72 Tajganj, Agra, Uttar Pradesh
# 10  27.160802  78.044126     True    526V+8M Tajganj, Agra, Uttar Pradesh
# 11  27.201420  78.003960     True             6223+HH Agra, Uttar Pradesh
# 12  27.163867  78.053754     True             5373+GG Agra, Uttar Pradesh
# 13  27.167869  78.008713     True  5295+4F Rakabganj, Agra, Uttar Pradesh
# 14  27.159612  78.043071    False    525V+R6 Tajganj, Agra, Uttar Pradesh
# 15  27.152723  78.062043     True             5336+3R Agra, Uttar Pradesh
# 16  27.162190  78.054552     True    5363+VR Tajganj, Agra, Uttar Pradesh
# 17  27.170986  78.044578      NaN             52CV+9R Agra, Uttar Pradesh
# 18  27.162880  78.036651     True  527P+5M Rakabganj, Agra, Uttar Pradesh
# 19  27.154162  78.053519     True    5333+MC Tajganj, Agra, Uttar Pradesh
# 20        NaN        NaN      NaN                                     NaN
# 21        NaN        NaN      NaN                                     NaN
# 22        NaN        NaN      NaN                                     NaN
#
#     global_code  avg
# 0   7JVW5353+FC  4.3
# 1   7JVW5345+HR  4.4
# 2   7JVW5355+5J  4.1
# 3   7JVW5342+W8  4.3
# 4   7JVW525F+GX  4.3
# 5   7JVW525M+8P  3.8
# 6   7JVW529R+Q6  3.9
# 7   7JVW5339+4P  4.2
# 8   7JVW5346+FW  3.6
# 9   7JVW5342+72  4.1
# 10  7JVW526V+8M  4.5
# 11  7JVW6223+HH  3.6
# 12  7JVW5373+GG  3.9
# 13  7JVW5295+4F  3.9
# 14  7JVW525V+R6  3.6
# 15  7JVW5336+3R  4.0
# 16  7JVW5363+VR  3.8
# 17  7JVW52CV+9R  3.4
# 18  7JVW527P+5M  4.2
# 19  7JVW5333+MC  4.0
# 20          NaN  NaN
# 21          NaN  NaN
# 22          NaN  NaN
#
# [23 rows x 170 columns]

# %%
y=finaldata.avg
y
# Out:
# 0     4.3
# 1     4.4
# 2     4.1
# 3     4.3
# 4     4.3
# 5     3.8
# 6     3.9
# 7     4.2
# 8     3.6
# 9     4.1
# 10    4.5
# 11    3.6
# 12    3.9
# 13    3.9
# 14    3.6
# 15    4.0
# 16    3.8
# 17    3.4
# 18    4.2
# 19    4.0
# 20    NaN
# 21    NaN
# 22    NaN
# Name: avg, dtype: float64

# %%
z=finaldata['avg'].apply(np.ceil)
z
# Out:
# 0     5.0
# 1     5.0
# 2     5.0
# 3     5.0
# 4     5.0
# 5     4.0
# 6     4.0
# 7     5.0
# 8     4.0
# 9     5.0
# 10    5.0
# 11    4.0
# 12    4.0
# 13    4.0
# 14    4.0
# 15    4.0
# 16    4.0
# 17    4.0
# 18    5.0
# 19    4.0
# 20    NaN
# 21    NaN
# 22    NaN
# Name: avg, dtype: float64

# %%
rate=(round(y))
rate
# Out:
# 0     4.0
# 1     4.0
# 2     4.0
# 3     4.0
# 4     4.0
# 5     4.0
# 6     4.0
# 7     4.0
# 8     4.0
# 9     4.0
# 10    4.0
# 11    4.0
# 12    4.0
# 13    4.0
# 14    4.0
# 15    4.0
# 16    4.0
# 17    3.0
# 18    4.0
# 19    4.0
# 20    NaN
# 21    NaN
# 22    NaN
# Name: avg, dtype: float64

# %%
StarRatingwithgoogle= finaldata[z == 4]
StarRatingwithgoogle
# Out:
#       HotelId                        HotelName CategoryList PropertyType  \
# 5   H!0280341                      The Retreat         None         None
# 6   H!0280321                Hotel Taj Resorts         None         None
# 8   H!0462437                Seven Hills Tower         None         None
# 11  H!0079211               The Grand Imperial         None         None
# 12  H!0062675                    Clarks Shiraz         None         None
# 13  H!0062677                  Mansingh Palace         None         None
# 14  H!0454839                Hotel Atulyaa Taj         None         None
# 15  H!0415457           Bhawna Clarks Inn Agra         None         None
# 16  H!0413011          Courtyard Marriott Agra         None         None
# 17  H!0047568  The Gateway Fatehabad Road Agra         None         None
# 19  H!0047573                     Trident Agra         None         None
#
#     IsPrime                                        Description HotelChain  \
# 5     False  Property Location With a stay at The Retreat i...
# 6     False  Property Location When you stay at Hotel Taj R...
# 8     False  Property Location With a stay at Hotel Seven H...
# 11    False  The hotel is located in the heart of the city,...
# 12    False  Property Location With a stay at Hotel Clarks ...
# 13    False  The hotel overlooks the man-made Ana Sagar Lak...
# 14    False  Property Location With a stay at Hotel Atulyaa...
# 15    False  Property Location With a stay at Bhawna Clarks...
# 16    False  This property is situated in Agra . Guests may...
# 17    False  Offering guests a view of the Taj Mahal from i...
# 19    False  This 5 star hotel is located within the city o...
#
#    StarRating  Rooms  MinRate  ... rating                    reference  \
# 5           3      0        0  ...    3.8  ChIJp9qXfTlxdDkRAsozoPqVabg
# 6           3      0        0  ...    3.9  ChIJMXpigyFxdDkRL6Ik_anr7l4
# 8           3      0        0  ...    3.6  ChIJU1UF3wpxdDkR8Tdtd6U0Ss8
# 11          4      0        0  ...    3.6  ChIJyd6qutB2dDkRZzysIn90Oy4
# 12          5      0        0  ...    3.9  ChIJRbIu3g9xdDkRAsxxN9O2CXE
# 13          4      0        0  ...    3.9  ChIJdcs3ubJ2dDkRK94NfY59hsE
# 14          3      0        0  ...    3.6  ChIJdxJhDhZxdDkR23DK1rVHJ6s
# 15          3      0        0  ...    4.0  ChIJ7wOj_HRxdDkR2-a5Z6yldRE
# 16          5      0        0  ...    3.8  ChIJe01IdhZxdDkRwUxqw_UZSpo
# 17          5      0        0  ...    3.4  ChIJye4YLh9xdDkRFcEwjjsQ7f4
# 19          5      0        0  ...    4.0  ChIJiyXXVG1xdDkRluGpZeg6K3I
#
#                                                 types user_ratings_total  \
# 5   [lodging, restaurant, food, point_of_interest,...              635.0
# 6         [lodging, point_of_interest, establishment]              486.0
# 8         [lodging, point_of_interest, establishment]              575.0
# 11        [lodging, point_of_interest, establishment]              456.0
# 12        [lodging, point_of_interest, establishment]              411.0
# 13  [lodging, restaurant, food, point_of_interest,...              436.0
# 14  [lodging, restaurant, food, point_of_interest,...              358.0
# 15        [lodging, point_of_interest, establishment]              734.0
# 16        [lodging, point_of_interest, establishment]              574.0
# 17        [lodging, point_of_interest, establishment]              220.0
# 19        [lodging, point_of_interest, establishment]              131.0
#
#           lat        lng open_now                           compound_code  \
# 5   27.158295  78.034290     True             525M+8P Agra, Uttar Pradesh
# 6   27.169388  78.040624      NaN             529R+Q6 Agra, Uttar Pradesh
# 8   27.156165  78.062312     True             5346+FW Agra, Uttar Pradesh
# 11  27.201420  78.003960     True             6223+HH Agra, Uttar Pradesh
# 12  27.163867  78.053754     True             5373+GG Agra, Uttar Pradesh
# 13  27.167869  78.008713     True  5295+4F Rakabganj, Agra, Uttar Pradesh
# 14  27.159612  78.043071    False    525V+R6 Tajganj, Agra, Uttar Pradesh
# 15  27.152723  78.062043     True             5336+3R Agra, Uttar Pradesh
# 16  27.162190  78.054552     True    5363+VR Tajganj, Agra, Uttar Pradesh
# 17  27.170986  78.044578      NaN             52CV+9R Agra, Uttar Pradesh
# 19  27.154162  78.053519     True    5333+MC Tajganj, Agra, Uttar Pradesh
#
#     global_code  avg
# 5   7JVW525M+8P  3.8
# 6   7JVW529R+Q6  3.9
# 8   7JVW5346+FW  3.6
# 11  7JVW6223+HH  3.6
# 12  7JVW5373+GG  3.9
# 13  7JVW5295+4F  3.9
# 14  7JVW525V+R6  3.6
# 15  7JVW5336+3R  4.0
# 16  7JVW5363+VR  3.8
# 17  7JVW52CV+9R  3.4
# 19  7JVW5333+MC  4.0
#
# [11 rows x 170 columns]

# %%
df1 = StarRatingwithgoogle.loc[:,~StarRatingwithgoogle.columns.duplicated()]

# %%
df1
# Out:
#       HotelId                        HotelName CategoryList PropertyType  \
# 5   H!0280341                      The Retreat         None         None
# 6   H!0280321                Hotel Taj Resorts         None         None
# 8   H!0462437                Seven Hills Tower         None         None
# 11  H!0079211               The Grand Imperial         None         None
# 12  H!0062675                    Clarks Shiraz         None         None
# 13  H!0062677                  Mansingh Palace         None         None
# 14  H!0454839                Hotel Atulyaa Taj         None         None
# 15  H!0415457           Bhawna Clarks Inn Agra         None         None
# 16  H!0413011          Courtyard Marriott Agra         None         None
# 17  H!0047568  The Gateway Fatehabad Road Agra         None         None
# 19  H!0047573                     Trident Agra         None         None
#
#     IsPrime                                        Description HotelChain  \
# 5     False  Property Location With a stay at The Retreat i...
# 6     False  Property Location When you stay at Hotel Taj R...
# 8     False  Property Location With a stay at Hotel Seven H...
# 11    False  The hotel is located in the heart of the city,...
# 12    False  Property Location With a stay at Hotel Clarks ...
# 13    False  The hotel overlooks the man-made Ana Sagar Lak...
# 14    False  Property Location With a stay at Hotel Atulyaa...
# 15    False  Property Location With a stay at Bhawna Clarks...
# 16    False  This property is situated in Agra . Guests may...
# 17    False  Offering guests a view of the Taj Mahal from i...
# 19    False  This 5 star hotel is located within the city o...
#
#    StarRating  Rooms  MinRate  ... rating                    reference  \
# 5           3      0        0  ...    3.8  ChIJp9qXfTlxdDkRAsozoPqVabg
# 6           3      0        0  ...    3.9  ChIJMXpigyFxdDkRL6Ik_anr7l4
# 8           3      0        0  ...    3.6  ChIJU1UF3wpxdDkR8Tdtd6U0Ss8
# 11          4      0        0  ...    3.6  ChIJyd6qutB2dDkRZzysIn90Oy4
# 12          5      0        0  ...    3.9  ChIJRbIu3g9xdDkRAsxxN9O2CXE
# 13          4      0        0  ...    3.9  ChIJdcs3ubJ2dDkRK94NfY59hsE
# 14          3      0        0  ...    3.6  ChIJdxJhDhZxdDkR23DK1rVHJ6s
# 15          3      0        0  ...    4.0  ChIJ7wOj_HRxdDkR2-a5Z6yldRE
# 16          5      0        0  ...    3.8  ChIJe01IdhZxdDkRwUxqw_UZSpo
# 17          5      0        0  ...    3.4  ChIJye4YLh9xdDkRFcEwjjsQ7f4
# 19          5      0        0  ...    4.0  ChIJiyXXVG1xdDkRluGpZeg6K3I
#
#                                                 types user_ratings_total  \
# 5   [lodging, restaurant, food, point_of_interest,...              635.0
# 6         [lodging, point_of_interest, establishment]              486.0
# 8         [lodging, point_of_interest, establishment]              575.0
# 11        [lodging, point_of_interest, establishment]              456.0
# 12        [lodging, point_of_interest, establishment]              411.0
# 13  [lodging, restaurant, food, point_of_interest,...              436.0
# 14  [lodging, restaurant, food, point_of_interest,...              358.0
# 15        [lodging, point_of_interest, establishment]              734.0
# 16        [lodging, point_of_interest, establishment]              574.0
# 17        [lodging, point_of_interest, establishment]              220.0
# 19        [lodging, point_of_interest, establishment]              131.0
#
#           lat        lng open_now                           compound_code  \
# 5   27.158295  78.034290     True             525M+8P Agra, Uttar Pradesh
# 6   27.169388  78.040624      NaN             529R+Q6 Agra, Uttar Pradesh
# 8   27.156165  78.062312     True             5346+FW Agra, Uttar Pradesh
# 11  27.201420  78.003960     True             6223+HH Agra, Uttar Pradesh
# 12  27.163867  78.053754     True             5373+GG Agra, Uttar Pradesh
# 13  27.167869  78.008713     True  5295+4F Rakabganj, Agra, Uttar Pradesh
# 14  27.159612  78.043071    False    525V+R6 Tajganj, Agra, Uttar Pradesh
# 15  27.152723  78.062043     True             5336+3R Agra, Uttar Pradesh
# 16  27.162190  78.054552     True    5363+VR Tajganj, Agra, Uttar Pradesh
# 17  27.170986  78.044578      NaN             52CV+9R Agra, Uttar Pradesh
# 19  27.154162  78.053519     True    5333+MC Tajganj, Agra, Uttar Pradesh
#
#     global_code  avg
# 5   7JVW525M+8P  3.8
# 6   7JVW529R+Q6  3.9
# 8   7JVW5346+FW  3.6
# 11  7JVW6223+HH  3.6
# 12  7JVW5373+GG  3.9
# 13  7JVW5295+4F  3.9
# 14  7JVW525V+R6  3.6
# 15  7JVW5336+3R  4.0
# 16  7JVW5363+VR  3.8
# 17  7JVW52CV+9R  3.4
# 19  7JVW5333+MC  4.0
#
# [11 rows x 74 columns]

# %%
df1.columns
# Out:
# Index(['HotelId', 'HotelName', 'CategoryList', 'PropertyType', 'IsPrime',
#        'Description', 'HotelChain', 'StarRating', 'Rooms', 'MinRate', 'RPH',
#        'WebService', 'HotelAddress', 'PostalCode', 'City', 'LocationInfo',
#        'PhoneNumber', 'Fax', 'Email', 'Website', 'Checkintime', 'Checkouttime',
#        'CreditCards', 'HotelServices', 'RoomServices', 'Facilities',
#        'CountryCode', 'AirportCode', 'SupplierType', 'PropertyCategory',
#        'Provider', 'RoomDetails', 'HotelImages', 'HotelPolicy',
#        'ConvenienceFee', 'ConvenienceFeeType', 'ConvenienceFeeTotal',
#        'AffiliateId', 'RoomCombination', 'RoomChain', 'Latitude', 'Longitude',
#        'Rating', 'Floors', 'Alias', 'Punchline', 'MapURL', 'VideoURL',
#        'PromoTitle', 'PromoDetail', 'Distances', 'AdditionalInfo', 'Awards',
#        'Events', 'OtherFees', 'Facebook', 'Twitter', 'Linkedin',
#        'formatted_address', 'icon', 'id', 'name', 'photos', 'place_id',
#        'rating', 'reference', 'types', 'user_ratings_total', 'lat', 'lng',
#        'open_now', 'compound_code', 'global_code', 'avg'],
#       dtype='object')

# %%
df1.HotelName
# Out:
# 5                         The Retreat
# 6                   Hotel Taj Resorts
# 8                   Seven Hills Tower
# 11                 The Grand Imperial
# 12                      Clarks Shiraz
# 13                    Mansingh Palace
# 14                  Hotel Atulyaa Taj
# 15             Bhawna Clarks Inn Agra
# 16            Courtyard Marriott Agra
# 17    The Gateway Fatehabad Road Agra
# 19                       Trident Agra
# Name: HotelName, dtype: object

# %%
json=df.to_json(r'Desktop//AvgStarRating.json')
