# %%
import numpy as np
import pandas as pd
import itertools
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
from pandas.io.json import json_normalize
import json

# %%
with open('C:/Users/akhan.extern/Desktop/jsondata/restaurants.json') as json_data:
    sample_object = json.load(json_data)

df = pd.io.json.json_normalize(sample_object)
df.columns = df.columns.map(lambda x: x.split(".")[-1])

print(df.shape)
# Out:
# (20, 58)

# %%
df.columns
# Out:
# Index(['delivery', 'takeaway', 'res_id', 'apikey', 'id', 'name', 'url',
#        'address', 'locality', 'city', 'city_id', 'latitude', 'longitude',
#        'zipcode', 'country_id', 'locality_verbose', 'switch_to_order_menu',
#        'cuisines', 'timings', 'average_cost_for_two', 'price_range',
#        'currency', 'highlights', 'offers', 'opentable_support',
#        'is_zomato_book_res', 'mezzo_provider', 'is_book_form_web_view',
#        'book_form_web_view_url', 'book_again_url', 'thumb', 'aggregate_rating',
#        'rating_text', 'rating_color', 'text', 'type', 'tint', 'votes',
#        'all_reviews_count', 'photos_url', 'photo_count', 'photos', 'menu_url',
#        'featured_image', 'has_online_delivery', 'is_delivering_now',
#        'include_bogo_offers', 'deeplink', 'order_url', 'order_deeplink',
#        'is_table_reservation_supported', 'has_table_booking', 'events_url',
#        'phone_numbers', 'reviews', 'establishment', 'establishment_types',
# ...

# %%
df.highlights
# Out:
# 0     [Dinner, Delivery, Lunch, Cash, Breakfast, Ind...
# 1     [Cash, Debit Card, Breakfast, No Alcohol Avail...
# 2     [Credit Card, Debit Card, Dinner, Delivery, Br...
# 3     [Dinner, Cash, Breakfast, Debit Card, Lunch, C...
# 4     [Lunch, Delivery, Dinner, Credit Card, Fullbar...
# 5     [Dinner, Cash, Lunch, Delivery, Breakfast, Ind...
# 6     [Credit Card, Dinner, Delivery, Lunch, Air Con...
# 7     [Dinner, Cash, Takeaway Available, Breakfast, ...
# 8     [Dinner, Cash, Takeaway Available, Debit Card,...
# 9     [Dinner, Delivery, Lunch, Cash, Takeaway Avail...
# 10    [Dinner, Delivery, Credit Card, Lunch, Cash, T...
# 11    [Dinner, Cash, Takeaway Available, Lunch, Deli...
# 12    [Lunch, Delivery, Debit Card, Dinner, Cash, Cr...
# 13    [Dinner, Cash, Credit Card, Lunch, Delivery, D...
# 14    [Dinner, Cash, Lunch, Delivery, Indoor Seating...
# 15    [Dinner, Cash, Takeaway Available, Lunch, Deli...
# 16    [Delivery, Breakfast, Dinner, Cash, Lunch, Out...
# ...

# %%
x = df["highlights"]=="Lunch"

# %%
y=df[x]

# %%
y
# Out:
# Empty DataFrame
# Columns: [delivery, takeaway, res_id, apikey, id, name, url, address, locality, city, city_id, latitude, longitude, zipcode, country_id, locality_verbose, switch_to_order_menu, cuisines, timings, average_cost_for_two, price_range, currency, highlights, offers, opentable_support, is_zomato_book_res, mezzo_provider, is_book_form_web_view, book_form_web_view_url, book_again_url, thumb, aggregate_rating, rating_text, rating_color, text, type, tint, votes, all_reviews_count, photos_url, photo_count, photos, menu_url, featured_image, has_online_delivery, is_delivering_now, include_bogo_offers, deeplink, order_url, order_deeplink, is_table_reservation_supported, has_table_booking, events_url, phone_numbers, reviews, establishment, establishment_types, zomato_events]
# Index: []
#
# [0 rows x 58 columns]

# %%
options = df['highlights']

# %%
options
# Out:
# 0     [Dinner, Delivery, Lunch, Cash, Breakfast, Ind...
# 1     [Cash, Debit Card, Breakfast, No Alcohol Avail...
# 2     [Credit Card, Debit Card, Dinner, Delivery, Br...
# 3     [Dinner, Cash, Breakfast, Debit Card, Lunch, C...
# 4     [Lunch, Delivery, Dinner, Credit Card, Fullbar...
# 5     [Dinner, Cash, Lunch, Delivery, Breakfast, Ind...
# 6     [Credit Card, Dinner, Delivery, Lunch, Air Con...
# 7     [Dinner, Cash, Takeaway Available, Breakfast, ...
# 8     [Dinner, Cash, Takeaway Available, Debit Card,...
# 9     [Dinner, Delivery, Lunch, Cash, Takeaway Avail...
# 10    [Dinner, Delivery, Credit Card, Lunch, Cash, T...
# 11    [Dinner, Cash, Takeaway Available, Lunch, Deli...
# 12    [Lunch, Delivery, Debit Card, Dinner, Cash, Cr...
# 13    [Dinner, Cash, Credit Card, Lunch, Delivery, D...
# 14    [Dinner, Cash, Lunch, Delivery, Indoor Seating...
# 15    [Dinner, Cash, Takeaway Available, Lunch, Deli...
# 16    [Delivery, Breakfast, Dinner, Cash, Lunch, Out...
# ...

# %%
len(options)
# Out:
# 20

# %%
for x in options:
  print(x)
# Out:
# ['Dinner', 'Delivery', 'Lunch', 'Cash', 'Breakfast', 'Indoor Seating']
# ['Cash', 'Debit Card', 'Breakfast', 'No Alcohol Available', 'Lunch', 'Credit Card', 'Takeaway Available', 'No Seating Available', 'Dinner', 'Sodexo']
# ['Credit Card', 'Debit Card', 'Dinner', 'Delivery', 'Breakfast', 'Lunch', 'Cash', 'Indoor Seating', 'Pure Veg']
# ['Dinner', 'Cash', 'Breakfast', 'Debit Card', 'Lunch', 'Credit Card', 'Indoor Seating', 'Table booking recommended', 'Buffet']
# ['Lunch', 'Delivery', 'Dinner', 'Credit Card', 'Fullbar', 'Air Conditioned', 'Indoor Seating', 'Smoking Area']
# ['Dinner', 'Cash', 'Lunch', 'Delivery', 'Breakfast', 'Indoor Seating', 'Pure Veg', 'Air Conditioned']
# ['Credit Card', 'Dinner', 'Delivery', 'Lunch', 'Air Conditioned', 'Fullbar', 'Indoor Seating']
# ['Dinner', 'Cash', 'Takeaway Available', 'Breakfast', 'Lunch', 'Delivery', 'Credit Card', 'Debit Card', 'Indoor Seating', 'Air Conditioned']
# ...

# %%
for y in x:
  print(y)
# Out:
# Dinner
# Delivery
# Credit Card
# Debit Card
# Lunch
# Cash
# Breakfast
# Indoor Seating
# Pure Veg

# %%
if y=='Delivery':
    print(df)

# %%
x = df['highlights'].apply(lambda x: 'Lunch' if x == 'Lunch' else 'Lunch')

# %%
x
# Out:
# 0     Lunch
# 1     Lunch
# 2     Lunch
# 3     Lunch
# 4     Lunch
# 5     Lunch
# 6     Lunch
# 7     Lunch
# 8     Lunch
# 9     Lunch
# 10    Lunch
# 11    Lunch
# 12    Lunch
# 13    Lunch
# 14    Lunch
# 15    Lunch
# 16    Lunch
# 17    Lunch
# 18    Lunch
# 19    Lunch
# Name: highlights, dtype: object

# %%
y=df[df['highlights'] == 'Delivery']

# %%
y
# Out:
# Empty DataFrame
# Columns: [delivery, takeaway, res_id, apikey, id, name, url, address, locality, city, city_id, latitude, longitude, zipcode, country_id, locality_verbose, switch_to_order_menu, cuisines, timings, average_cost_for_two, price_range, currency, highlights, offers, opentable_support, is_zomato_book_res, mezzo_provider, is_book_form_web_view, book_form_web_view_url, book_again_url, thumb, aggregate_rating, rating_text, rating_color, text, type, tint, votes, all_reviews_count, photos_url, photo_count, photos, menu_url, featured_image, has_online_delivery, is_delivering_now, include_bogo_offers, deeplink, order_url, order_deeplink, is_table_reservation_supported, has_table_booking, events_url, phone_numbers, reviews, establishment, establishment_types, zomato_events]
# Index: []
#
# [0 rows x 58 columns]

# %%
x=df.highlights.tolist()
x
# Out:
# [['Dinner', 'Delivery', 'Lunch', 'Cash', 'Breakfast', 'Indoor Seating'],
#  ['Cash',
#   'Debit Card',
#   'Breakfast',
#   'No Alcohol Available',
#   'Lunch',
#   'Credit Card',
#   'Takeaway Available',
#   'No Seating Available',
#   'Dinner',
#   'Sodexo'],
#  ['Credit Card',
#   'Debit Card',
#   'Dinner',
#   'Delivery',
#   'Breakfast',
#   'Lunch',
#   'Cash',
#   'Indoor Seating',
#   'Pure Veg'],
#  ['Dinner',
#   'Cash',
#   'Breakfast',
#   'Debit Card',
#   'Lunch',
#   'Credit Card',
#   'Indoor Seating',
#   'Table booking recommended',
#   'Buffet'],
#  ['Lunch',
#   'Delivery',
#   'Dinner',
#   'Credit Card',
#   'Fullbar',
#   'Air Conditioned',
#   'Indoor Seating',
#   'Smoking Area'],
#  ['Dinner',
#   'Cash',
#   'Lunch',
#   'Delivery',
#   'Breakfast',
#   'Indoor Seating',
#   'Pure Veg',
#   'Air Conditioned'],
#  ['Credit Card',
#   'Dinner',
#   'Delivery',
#   'Lunch',
#   'Air Conditioned',
#   'Fullbar',
#   'Indoor Seating'],
#  ['Dinner',
# ...

# %%
cols = ['highlights']
conditions = ['Delivery']

# %%
 df[eval(" & ".join(["(df['{0}'] == {1})".format(col, repr(cond)) 
            for col, cond in zip(cols, conditions)]))]
# Out:
# Empty DataFrame
# Columns: [delivery, takeaway, res_id, apikey, id, name, url, address, locality, city, city_id, latitude, longitude, zipcode, country_id, locality_verbose, switch_to_order_menu, cuisines, timings, average_cost_for_two, price_range, currency, highlights, offers, opentable_support, is_zomato_book_res, mezzo_provider, is_book_form_web_view, book_form_web_view_url, book_again_url, thumb, aggregate_rating, rating_text, rating_color, text, type, tint, votes, all_reviews_count, photos_url, photo_count, photos, menu_url, featured_image, has_online_delivery, is_delivering_now, include_bogo_offers, deeplink, order_url, order_deeplink, is_table_reservation_supported, has_table_booking, events_url, phone_numbers, reviews, establishment, establishment_types, zomato_events]
# Index: []
#
# [0 rows x 58 columns]

# %%
search_values = ['Delivery']

# %%
x=df['highlights'].str.contains("Delivery")

# %%
for idx, row1 in enumerate(range(0, len(df))):
    if df.iloc[row1]['highlights'] == 'Delivery':
        df.set_value(df.index[row1], 'name', abc[idx])
print(df)
# Out:
#     delivery  takeaway    res_id                            apikey        id  \
# 0          1        -1     39740  37e2e0600b5cd6d2476fe070452f0ecc     39740
# 1         -1        -1  18285954  37e2e0600b5cd6d2476fe070452f0ecc  18285954
# 2         -1        -1     35604  37e2e0600b5cd6d2476fe070452f0ecc     35604
# 3         -1        -1  18746514  37e2e0600b5cd6d2476fe070452f0ecc  18746514
# 4         -1        -1     49308  37e2e0600b5cd6d2476fe070452f0ecc     49308
# 5          1        -1     34115  37e2e0600b5cd6d2476fe070452f0ecc     34115
# 6         -1        -1     42774  37e2e0600b5cd6d2476fe070452f0ecc     42774
# 7          1        -1     35616  37e2e0600b5cd6d2476fe070452f0ecc     35616
# 8         -1        -1  18759983  37e2e0600b5cd6d2476fe070452f0ecc  18759983
# 9         -1        -1  18544310  37e2e0600b5cd6d2476fe070452f0ecc  18544310
# 10        -1        -1  18760924  37e2e0600b5cd6d2476fe070452f0ecc  18760924
# ...

# %%
 lst_col = 'highlights'

# %%
data= pd.DataFrame({
       col:np.repeat(df[col].values, df[lst_col].str.len())
         for col in df.columns.difference([lst_col])
      }).assign(**{lst_col:np.concatenate(df[lst_col].values)})[df.columns.tolist()]

# %%
data
# Out:
#      delivery  takeaway  res_id                            apikey     id  \
# 0           1        -1   39740  37e2e0600b5cd6d2476fe070452f0ecc  39740
# 1           1        -1   39740  37e2e0600b5cd6d2476fe070452f0ecc  39740
# 2           1        -1   39740  37e2e0600b5cd6d2476fe070452f0ecc  39740
# 3           1        -1   39740  37e2e0600b5cd6d2476fe070452f0ecc  39740
# 4           1        -1   39740  37e2e0600b5cd6d2476fe070452f0ecc  39740
# ..        ...       ...     ...                               ...    ...
# 156         1        -1   32683  37e2e0600b5cd6d2476fe070452f0ecc  32683
# 157         1        -1   32683  37e2e0600b5cd6d2476fe070452f0ecc  32683
# 158         1        -1   32683  37e2e0600b5cd6d2476fe070452f0ecc  32683
# 159         1        -1   32683  37e2e0600b5cd6d2476fe070452f0ecc  32683
# 160         1        -1   32683  37e2e0600b5cd6d2476fe070452f0ecc  32683
#
#                     name                                                url  \
# ...

# %%
Delivery=data[data['highlights'] == Delivery]

# %%
Delivery
# Out:
#      delivery  takeaway    res_id                            apikey        id  \
# 1           1        -1     39740  37e2e0600b5cd6d2476fe070452f0ecc     39740
# 19         -1        -1     35604  37e2e0600b5cd6d2476fe070452f0ecc     35604
# 35         -1        -1     49308  37e2e0600b5cd6d2476fe070452f0ecc     49308
# 45          1        -1     34115  37e2e0600b5cd6d2476fe070452f0ecc     34115
# 52         -1        -1     42774  37e2e0600b5cd6d2476fe070452f0ecc     42774
# 62          1        -1     35616  37e2e0600b5cd6d2476fe070452f0ecc     35616
# 72         -1        -1  18759983  37e2e0600b5cd6d2476fe070452f0ecc  18759983
# 77         -1        -1  18544310  37e2e0600b5cd6d2476fe070452f0ecc  18544310
# 83         -1        -1  18760924  37e2e0600b5cd6d2476fe070452f0ecc  18760924
# 96         -1        -1  19072680  37e2e0600b5cd6d2476fe070452f0ecc  19072680
# 101        -1        -1     34132  37e2e0600b5cd6d2476fe070452f0ecc     34132
# ...

# %%
Dinner=data[data['highlights'] =='Dinner']

# %%
Dinner
# Out:
#      delivery  takeaway    res_id                            apikey        id  \
# 0           1        -1     39740  37e2e0600b5cd6d2476fe070452f0ecc     39740
# 14         -1        -1  18285954  37e2e0600b5cd6d2476fe070452f0ecc  18285954
# 18         -1        -1     35604  37e2e0600b5cd6d2476fe070452f0ecc     35604
# 25         -1        -1  18746514  37e2e0600b5cd6d2476fe070452f0ecc  18746514
# 36         -1        -1     49308  37e2e0600b5cd6d2476fe070452f0ecc     49308
# 42          1        -1     34115  37e2e0600b5cd6d2476fe070452f0ecc     34115
# 51         -1        -1     42774  37e2e0600b5cd6d2476fe070452f0ecc     42774
# 57          1        -1     35616  37e2e0600b5cd6d2476fe070452f0ecc     35616
# 67         -1        -1  18759983  37e2e0600b5cd6d2476fe070452f0ecc  18759983
# 76         -1        -1  18544310  37e2e0600b5cd6d2476fe070452f0ecc  18544310
# 82         -1        -1  18760924  37e2e0600b5cd6d2476fe070452f0ecc  18760924
# ...

# %%
Breakfast=data[data['highlights'] =='Breakfast']

# %%
Breakfast
# Out:
#      delivery  takeaway    res_id                            apikey        id  \
# 4           1        -1     39740  37e2e0600b5cd6d2476fe070452f0ecc     39740
# 8          -1        -1  18285954  37e2e0600b5cd6d2476fe070452f0ecc  18285954
# 20         -1        -1     35604  37e2e0600b5cd6d2476fe070452f0ecc     35604
# 27         -1        -1  18746514  37e2e0600b5cd6d2476fe070452f0ecc  18746514
# 46          1        -1     34115  37e2e0600b5cd6d2476fe070452f0ecc     34115
# 60          1        -1     35616  37e2e0600b5cd6d2476fe070452f0ecc     35616
# 132        -1        -1  16529647  37e2e0600b5cd6d2476fe070452f0ecc  16529647
# 146        -1        -1     36868  37e2e0600b5cd6d2476fe070452f0ecc     36868
# 158         1        -1     32683  37e2e0600b5cd6d2476fe070452f0ecc     32683
#
#                        name  \
# 4       Rajdhani Restaurant
# 8            Domino's Pizza
# 20   Pallavi Veg Restaurant
# 27             Gallery Café
# 46              Jai Hanuman
# ...

# %%
list(data.highlights.values)
# Out:
# ['Dinner',
#  'Delivery',
#  'Lunch',
#  'Cash',
#  'Breakfast',
#  'Indoor Seating',
#  'Cash',
#  'Debit Card',
#  'Breakfast',
#  'No Alcohol Available',
#  'Lunch',
#  'Credit Card',
#  'Takeaway Available',
#  'No Seating Available',
#  'Dinner',
#  'Sodexo',
#  'Credit Card',
#  'Debit Card',
#  'Dinner',
#  'Delivery',
#  'Breakfast',
#  'Lunch',
#  'Cash',
#  'Indoor Seating',
#  'Pure Veg',
#  'Dinner',
#  'Cash',
#  'Breakfast',
#  'Debit Card',
#  'Lunch',
#  'Credit Card',
#  'Indoor Seating',
#  'Table booking recommended',
#  'Buffet',
#  'Lunch',
#  'Delivery',
#  'Dinner',
#  'Credit Card',
#  'Fullbar',
#  'Air Conditioned',
#  'Indoor Seating',
#  'Smoking Area',
#  'Dinner',
#  'Cash',
#  'Lunch',
#  'Delivery',
#  'Breakfast',
#  'Indoor Seating',
#  'Pure Veg',
#  'Air Conditioned',
#  'Credit Card',
#  'Dinner',
#  'Delivery',
#  'Lunch',
#  'Air Conditioned',
#  'Fullbar',
#  'Indoor Seating',
#  'Dinner',
#  'Cash',
#  'Takeaway Available',
#  'Breakfast',
# ...

# %%
Lunch=data[data['highlights'] =='Lunch']

# %%
Lunch
# Out:
#      delivery  takeaway    res_id                            apikey        id  \
# 2           1        -1     39740  37e2e0600b5cd6d2476fe070452f0ecc     39740
# 10         -1        -1  18285954  37e2e0600b5cd6d2476fe070452f0ecc  18285954
# 21         -1        -1     35604  37e2e0600b5cd6d2476fe070452f0ecc     35604
# 29         -1        -1  18746514  37e2e0600b5cd6d2476fe070452f0ecc  18746514
# 34         -1        -1     49308  37e2e0600b5cd6d2476fe070452f0ecc     49308
# 44          1        -1     34115  37e2e0600b5cd6d2476fe070452f0ecc     34115
# 53         -1        -1     42774  37e2e0600b5cd6d2476fe070452f0ecc     42774
# 61          1        -1     35616  37e2e0600b5cd6d2476fe070452f0ecc     35616
# 71         -1        -1  18759983  37e2e0600b5cd6d2476fe070452f0ecc  18759983
# 78         -1        -1  18544310  37e2e0600b5cd6d2476fe070452f0ecc  18544310
# 85         -1        -1  18760924  37e2e0600b5cd6d2476fe070452f0ecc  18760924
# ...

# %%
Fullbar=data[data['highlights'] =='Fullbar']

# %%
Fullbar
# Out:
#      delivery  takeaway  res_id                            apikey     id  \
# 38         -1        -1   49308  37e2e0600b5cd6d2476fe070452f0ecc  49308
# 55         -1        -1   42774  37e2e0600b5cd6d2476fe070452f0ecc  42774
# 106        -1        -1   34132  37e2e0600b5cd6d2476fe070452f0ecc  34132
# 143         1        -1   35576  37e2e0600b5cd6d2476fe070452f0ecc  35576
#
#                                  name  \
# 38   Shree Krishna Lunch Home and Bar
# 55             Laxmi Bar & Restaurant
# 106                         Vrindavan
# 143                      Hotel Satish
#
#                                                    url  \
# 38   https://www.zomato.com/mumbai/shree-krishna-lu...
# 55   https://www.zomato.com/mumbai/laxmi-bar-restau...
# 106  https://www.zomato.com/mumbai/vrindavan-near-a...
# 143  https://www.zomato.com/mumbai/hotel-satish-nea...
#
#                                                address  \
# 38   Andheri Kurla Road, Opposite Andheri Railway S...
# ...

# %%
PureVeg=data[data['highlights'] =='Pure Veg']

# %%
PureVeg
# Out:
#      delivery  takeaway    res_id                            apikey        id  \
# 24         -1        -1     35604  37e2e0600b5cd6d2476fe070452f0ecc     35604
# 48          1        -1     34115  37e2e0600b5cd6d2476fe070452f0ecc     34115
# 122        -1        -1     35605  37e2e0600b5cd6d2476fe070452f0ecc     35605
# 137        -1        -1  16529647  37e2e0600b5cd6d2476fe070452f0ecc  16529647
# 151        -1        -1     36868  37e2e0600b5cd6d2476fe070452f0ecc     36868
# 160         1        -1     32683  37e2e0600b5cd6d2476fe070452f0ecc     32683
#
#                              name  \
# 24         Pallavi Veg Restaurant
# 48                    Jai Hanuman
# 122  Prasadam Pure Veg Restaurant
# 137            Prestige Veg Treat
# 151                         Arasa
# 160                       Sarovar
#
#                                                    url  \
# 24   https://www.zomato.com/mumbai/pallavi-veg-rest...
# 48   https://www.zomato.com/mumbai/jai-hanuman-near...
# ...

# %%
dataTypeSeries = df.dtypes

# %%
dataTypeSeries
# Out:
# delivery                           int64
# takeaway                           int64
# res_id                             int64
# apikey                            object
# id                                object
# name                              object
# url                               object
# address                           object
# locality                          object
# city                              object
# city_id                            int64
# latitude                          object
# longitude                         object
# zipcode                           object
# country_id                         int64
# locality_verbose                  object
# switch_to_order_menu               int64
# cuisines                          object
# timings                           object
# average_cost_for_two               int64
# price_range                        int64
# currency                          object
# highlights                        object
# ...

# %%
x=df['establishment'].astype(str)
x
# Out:
# 0       ['Quick Bites']
# 1       ['Quick Bites']
# 2       ['Quick Bites']
# 3     ['Casual Dining']
# 4     ['Casual Dining']
# 5       ['Quick Bites']
# 6     ['Casual Dining']
# 7     ['Casual Dining']
# 8     ['Casual Dining']
# 9       ['Quick Bites']
# 10    ['Casual Dining']
# 11    ['Casual Dining']
# 12    ['Casual Dining']
# 13    ['Casual Dining']
# 14      ['Quick Bites']
# 15      ['Quick Bites']
# 16    ['Casual Dining']
# 17    ['Casual Dining']
# 18    ['Casual Dining']
# 19      ['Quick Bites']
# Name: establishment, dtype: object

# %%
with open('C:/analysis/datafiles/restaurents/anjum.json') as json_data:
    sample_object = json.load(json_data)

data = pd.io.json.json_normalize(sample_object)
data.columns = data.columns.map(lambda x: x.split(".")[-1])

print(data.shape)
# Out:
# (20, 60)

# %%
df_row = pd.concat([df, data],ignore_index=True)
# Out:
# C:\Users\akhan.extern\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df_row
# Out:
#                                               address aggregate_rating  \
# 0   New Nagardas Road, Andheri East, Near Andheri ...              3.2
# 1   Andheri Metro Station, Near Andheri East Stati...              3.8
# 2   28, Gopal Bhavan, Azad Road, Andheri East, Nea...              3.8
# 3   X - 22, MIDC Central Road, Andheri East, Near ...              3.9
# 4   Andheri Kurla Road, Opposite Andheri Railway S...              3.1
# 5   Old Nagardas Road, Near Andheri Subway, Near A...              3.6
# 6   Morga Village Road, Near Andheri Subway, Near ...              3.2
# 7   Shop 5, N Vidya Villa 1, Old Nagardas Road, Ne...              4.0
# 8    Baba Ramdevji, Near Andheri East Station, Mumbai              3.0
# 9      Vijay Nagar, Near Andheri East Station, Mumbai                0
# 10  Opposite Bahar Talkies, Sahar Road, Junction o...              2.9
# 11  Parsiwada, Sahar Road, Near Andheri East Stati...              3.2
# ...

# %%
df_row.shape
# Out:
# (40, 60)

# %%
df_row.columns
# Out:
# Index(['address', 'aggregate_rating', 'all_reviews_count', 'apikey',
#        'average_cost_for_two', 'book_again_url', 'book_form_web_view_url',
#        'book_url', 'city', 'city_id', 'country_id', 'cuisines', 'currency',
#        'deeplink', 'delivery', 'establishment', 'establishment_types',
#        'events_url', 'featured_image', 'has_online_delivery',
#        'has_table_booking', 'highlights', 'id', 'include_bogo_offers',
#        'is_book_form_web_view', 'is_delivering_now',
#        'is_table_reservation_supported', 'is_zomato_book_res', 'latitude',
#        'locality', 'locality_verbose', 'longitude', 'medio_provider',
#        'menu_url', 'mezzo_provider', 'name', 'offers', 'opentable_support',
#        'order_deeplink', 'order_url', 'phone_numbers', 'photo_count', 'photos',
#        'photos_url', 'price_range', 'rating_color', 'rating_text', 'res_id',
#        'reviews', 'switch_to_order_menu', 'takeaway', 'text', 'thumb',
# ...

# %%
x=df.name
x
# Out:
# 0                  Rajdhani Restaurant
# 1                       Domino's Pizza
# 2               Pallavi Veg Restaurant
# 3                         Gallery Café
# 4     Shree Krishna Lunch Home and Bar
# 5                          Jai Hanuman
# 6               Laxmi Bar & Restaurant
# 7                   Sarvodaya Pure Veg
# 8               Swaad Restaurant & Bar
# 9                    Sunny Food Corner
# 10                   Miraas Restaurant
# 11                      Sizzling China
# 12                           Vrindavan
# 13                      Kishore Punjab
# 14        Prasadam Pure Veg Restaurant
# 15                        Hotel Om Sai
# 16                  Prestige Veg Treat
# 17                        Hotel Satish
# 18                               Arasa
# 19                             Sarovar
# Name: name, dtype: object

# %%
x=(df.aggregate_rating).astype(float)

# %%
x
# Out:
# 0     3.2
# 1     3.8
# 2     3.8
# 3     3.9
# 4     3.1
# 5     3.6
# 6     3.2
# 7     4.0
# 8     3.0
# 9     0.0
# 10    2.9
# 11    3.2
# 12    3.6
# 13    3.4
# 14    3.7
# 15    0.0
# 16    3.5
# 17    2.9
# 18    3.6
# 19    3.7
# Name: aggregate_rating, dtype: float64

# %%
ratingdata=(round(x))
ratingdata
# Out:
# 0     3.0
# 1     4.0
# 2     4.0
# 3     4.0
# 4     3.0
# 5     4.0
# 6     3.0
# 7     4.0
# 8     3.0
# 9     0.0
# 10    3.0
# 11    3.0
# 12    4.0
# 13    3.0
# 14    4.0
# 15    0.0
# 16    4.0
# 17    3.0
# 18    4.0
# 19    4.0
# Name: aggregate_rating, dtype: float64

# %%
store= df[ratingdata > 4 ]

# %%
store
# Out:
# Empty DataFrame
# Columns: [delivery, takeaway, res_id, apikey, id, name, url, address, locality, city, city_id, latitude, longitude, zipcode, country_id, locality_verbose, switch_to_order_menu, cuisines, timings, average_cost_for_two, price_range, currency, highlights, offers, opentable_support, is_zomato_book_res, mezzo_provider, is_book_form_web_view, book_form_web_view_url, book_again_url, thumb, aggregate_rating, rating_text, rating_color, text, type, tint, votes, all_reviews_count, photos_url, photo_count, photos, menu_url, featured_image, has_online_delivery, is_delivering_now, include_bogo_offers, deeplink, order_url, order_deeplink, is_table_reservation_supported, has_table_booking, events_url, phone_numbers, reviews, establishment, establishment_types, zomato_events]
# Index: []
#
# [0 rows x 58 columns]

# %%
store.address
# Out:
# 0     G-2B, Ground Floor, Maker Maxity 3, North Aven...
# 1     14, Silver Beach Estate, A.B. Nair Road, Oppos...
# 2     002, First International Financial Centre, G B...
# 3     1st Floor, Chandiwala Heritage, Opposite Goreg...
# 4     Hotel Executive Enclave, 331, Dr Ambedkar Road...
# 6     Unit 4, Ground Floor, Jet Airways, Godrej G Bl...
# 7     5th Floor, Crystal Point Mall, Andheri Lokhand...
# 8     Ramee Guestline Hotel, 462, A.B. Nair Road, Ju...
# 9     Top Floor, Chandiwala Arcade, Goregaon Link Ro...
# 10    5, Transocean, Hiranandani Business Park, Lake...
# 11    Unit T-9, 3rd Floor, High Street Phoenix Mall,...
# 13    1st Floor, Vibgyor Towers, Bandra Kurla Comple...
# 14    9, Ground Floor, Raheja Classic Complex, Near ...
# 15    1, Ground Floor, Transocean House, Lake Blve R...
# 16    Plot B10, CTS 608, 2nd Floor, Gopi Chamber, Os...
# 18    Plot B, Floor 1, Opposite Citi Mall, Ghanshyam...
# Name: address, dtype: object

# %%
maroldata=store[store['address'].str.contains("Andheri")]

# %%
df.highlights
# Out:
# 0     [Dinner, Delivery, Lunch, Cash, Breakfast, Ind...
# 1     [Cash, Debit Card, Breakfast, No Alcohol Avail...
# 2     [Credit Card, Debit Card, Dinner, Delivery, Br...
# 3     [Dinner, Cash, Breakfast, Debit Card, Lunch, C...
# 4     [Lunch, Delivery, Dinner, Credit Card, Fullbar...
# 5     [Dinner, Cash, Lunch, Delivery, Breakfast, Ind...
# 6     [Credit Card, Dinner, Delivery, Lunch, Air Con...
# 7     [Dinner, Cash, Takeaway Available, Breakfast, ...
# 8     [Dinner, Cash, Takeaway Available, Debit Card,...
# 9     [Dinner, Delivery, Lunch, Cash, Takeaway Avail...
# 10    [Dinner, Delivery, Credit Card, Lunch, Cash, T...
# 11    [Dinner, Cash, Takeaway Available, Lunch, Deli...
# 12    [Lunch, Delivery, Debit Card, Dinner, Cash, Cr...
# 13    [Dinner, Cash, Credit Card, Lunch, Delivery, D...
# 14    [Dinner, Cash, Lunch, Delivery, Indoor Seating...
# 15    [Dinner, Cash, Takeaway Available, Lunch, Deli...
# 16    [Delivery, Breakfast, Dinner, Cash, Lunch, Out...
# ...

# %%
maroldata
# Out:
#     delivery  takeaway    res_id                            apikey        id  \
# 7         -1        -1  19030263  ede9fbb1b319aa0d249f4369889015ae  19030263
# 14        -1        -1  18934741  ede9fbb1b319aa0d249f4369889015ae  18934741
# 16        -1        -1  19235634  ede9fbb1b319aa0d249f4369889015ae  19235634
#
#                                name  \
# 7   Sin City Rooftop Resto & Lounge
# 14     Yazu - Pan Asian Supper Club
# 16                The Flying Saucer
#
#                                                   url  \
# 7   https://www.zomato.com/mumbai/sin-city-rooftop...
# 14  https://www.zomato.com/mumbai/yazu-pan-asian-s...
# 16  https://www.zomato.com/mumbai/the-flying-sauce...
#
#                                               address  \
# 7   5th Floor, Crystal Point Mall, Andheri Lokhand...
# 14  9, Ground Floor, Raheja Classic Complex, Near ...
# 16  Plot B10, CTS 608, 2nd Floor, Gopi Chamber, Os...
#
#                              locality    city  ...  \
# ...

# %%
y=store.average_cost_for_two
y
# Out:
# 0     3000
# 1     3000
# 2     1600
# 3     1400
# 4     2200
# 6     1500
# 7     2500
# 8     1500
# 9     2000
# 10    1600
# 11    3000
# 13    2000
# 14    2200
# 15    3000
# 16    1900
# 18    1300
# Name: average_cost_for_two, dtype: int64

# %%
cost= store[y > 1300 ]

# %%
cost
# Out:
#     delivery  takeaway    res_id                            apikey        id  \
# 0         -1        -1  19044567  ede9fbb1b319aa0d249f4369889015ae  19044567
# 1         -1        -1  18962112  ede9fbb1b319aa0d249f4369889015ae  18962112
# 2         -1        -1  18591040  ede9fbb1b319aa0d249f4369889015ae  18591040
# 3         -1        -1  18521607  ede9fbb1b319aa0d249f4369889015ae  18521607
# 4         -1        -1  18357374  ede9fbb1b319aa0d249f4369889015ae  18357374
# 6         -1        -1  18707459  ede9fbb1b319aa0d249f4369889015ae  18707459
# 7         -1        -1  19030263  ede9fbb1b319aa0d249f4369889015ae  19030263
# 8         -1        -1  18599546  ede9fbb1b319aa0d249f4369889015ae  18599546
# 9         -1        -1  17805700  ede9fbb1b319aa0d249f4369889015ae  17805700
# 10        -1        -1  18548172  ede9fbb1b319aa0d249f4369889015ae  18548172
# 11        -1        -1  19153622  ede9fbb1b319aa0d249f4369889015ae  19153622
# ...

# %%
 import pymongo
