# %%
import numpy as np
import pandas as pd
import itertools
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
from pandas.io.json import json_normalize
import json

# %%
with open('C:/Users/akhan.extern/Desktop/jsondata/chennai.json') as json_data:
    sample_object = json.load(json_data)

df = pd.io.json.json_normalize(sample_object)
df.columns = df.columns.map(lambda x: x.split(".")[-1])

print(df.shape)
# Out:
# (52, 58)

# %%
df
# Out:
#       HotelId                                HotelName CategoryList  \
# 0   H!0098866                                The Pride         None
# 1   H!0363558             The Westin Chennai Velachery         None
# 2   H!0394133                           Peace Park Inn         None
# 3   H!0400763                          Kohinoor Asiana         None
# 4   H!0462436        Southern Residency Chennai Sipcot         None
# 5   H!0242091                              Royal Plaza         None
# 6   H!0496680      Rainbow Hotels & Service Apartments         None
# 7   H!0187770                                 Raj Park         None
# 8   H!0101374                      Abu Sarovar Portico         None
# 9   H!0431778                   Days Hotel Chennai OMR         None
# 10  H!0281350                             Asiana Place         None
# 11  H!0047514                         The Park Chennai         None
# 12  H!0157336                                Courtyard         None
# ...

# %%
df.columns
# Out:
# Index(['HotelId', 'HotelName', 'CategoryList', 'PropertyType', 'IsPrime',
#        'Description', 'HotelChain', 'StarRating', 'Rooms', 'MinRate', 'RPH',
#        'WebService', 'HotelAddress', 'PostalCode', 'City', 'LocationInfo',
#        'PhoneNumber', 'Fax', 'Email', 'Website', 'Checkintime', 'Checkouttime',
#        'CreditCards', 'HotelServices', 'RoomServices', 'Facilities',
#        'CountryCode', 'AirportCode', 'SupplierType', 'PropertyCategory',
#        'Provider', 'RoomDetails', 'HotelImages', 'HotelPolicy',
#        'ConvenienceFee', 'ConvenienceFeeType', 'ConvenienceFeeTotal',
#        'AffiliateId', 'RoomCombination', 'RoomChain', 'Latitude', 'Longitude',
#        'Rating', 'Floors', 'Alias', 'Punchline', 'MapURL', 'VideoURL',
#        'PromoTitle', 'PromoDetail', 'Distances', 'AdditionalInfo', 'Awards',
#        'Events', 'OtherFees', 'Facebook', 'Twitter', 'Linkedin'],
#       dtype='object')

# %%
x=(df.StarRating).astype(float)

# %%
StarRating= df[x == 5 ]
StarRating.head()
# Out:
#       HotelId                     HotelName CategoryList PropertyType  \
# 1   H!0363558  The Westin Chennai Velachery         None         None
# 3   H!0400763               Kohinoor Asiana         None         None
# 11  H!0047514              The Park Chennai         None         None
# 14  H!0157432                Taj Club House         None         None
# 15  H!0047513     Le Royal Meridien Chennai         None         None
#
#     IsPrime                                        Description HotelChain  \
# 1     False  Situated right on the edge of Guindy National ...
# 3     False  The hotel, stringing together a spectacular se...
# 11    False  Situated in Chennais business district, the lu...
# 14    False  Located on Clubhouse road,It is famous for its...
# 15    False  The hotel is ideally set among 3.5 acres of ex...
#
#    StarRating  Rooms  MinRate  ... PromoTitle PromoDetail Distances  \
# 1           5      0        0  ...       None        None      None
# ...

# %%
json=StarRating.to_json(r'Desktop//chennai_starrating.json')
