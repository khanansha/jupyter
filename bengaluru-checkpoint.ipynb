# %%
import numpy as np
import pandas as pd
import itertools
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
from pandas.io.json import json_normalize
import json

# %%
with open('C:/Users/akhan.extern/Desktop/jsondata/bengaluru.json',encoding="utf8") as json_data:
    sample_object = json.load(json_data)

df = pd.io.json.json_normalize(sample_object)
#df.columns = df.columns.map(lambda x: x.split(".")[-1])

print(df.shape)
# Out:
# (95, 58)

# %%
df.head()
# Out:
#      HotelId                           HotelName CategoryList PropertyType  \
# 0  H!0531312  Orange Suites Airport Transit Stay         None         None
# 1  H!0513751       OYO Rooms Manyata Tech Park 2         None         None
# 2  H!0237539                    The Curzon Court         None         None
# 3  H!0246245              The Fern Citadel Hotel         None         None
# 4  H!0512428            Bloomrooms @ Indiranagar         None         None
#
#    IsPrime                                        Description HotelChain  \
# 0    False  Property Location With a stay at Orange Suites...
# 1    False  Property Location When you stay at OYO Rooms M...
# 2    False  Property Location With a stay at The Curzon Co...
# 3    False  Strategically located at a distance of about 3...
# 4    False  Property Location Located in Bengaluru (Indira...
#
#   StarRating  Rooms  MinRate  ... PromoTitle PromoDetail Distances  \
# ...

# %%
df.columns
# Out:
# Index(['HotelId', 'HotelName', 'CategoryList', 'PropertyType', 'IsPrime',
#        'Description', 'HotelChain', 'StarRating', 'Rooms', 'MinRate', 'RPH',
#        'WebService', 'HotelAddress', 'PostalCode', 'City', 'LocationInfo',
#        'PhoneNumber', 'Fax', 'Email', 'Website', 'Checkintime', 'Checkouttime',
#        'CreditCards', 'HotelServices', 'RoomServices', 'Facilities',
#        'CountryCode', 'AirportCode', 'SupplierType', 'PropertyCategory',
#        'Provider', 'RoomDetails', 'HotelImages', 'HotelPolicy',
#        'ConvenienceFee', 'ConvenienceFeeType', 'ConvenienceFeeTotal',
#        'AffiliateId', 'RoomCombination', 'RoomChain', 'Latitude', 'Longitude',
#        'Rating', 'Floors', 'Alias', 'Punchline', 'MapURL', 'VideoURL',
#        'PromoTitle', 'PromoDetail', 'Distances', 'AdditionalInfo', 'Awards',
#        'Events', 'OtherFees', 'Facebook', 'Twitter', 'Linkedin'],
#       dtype='object')

# %%
x=(df.StarRating).astype(float)

# %%
StarRating= df[x == 5 ]
StarRating.head()
# Out:
#       HotelId                   HotelName CategoryList PropertyType  IsPrime  \
# 9   H!0047560        The Oberoi Bangalore         None         None    False
# 27  H!0242075         The Zuri Whitefield         None         None    False
# 29  H!0246259         Sterlings Mac Hotel         None         None    False
# 32  H!0128871            The Leela Palace         None         None    False
# 33  H!0391738  The Ritz-Carlton Bangalore         None         None    False
#
#                                           Description HotelChain StarRating  \
# 9   The Oberoi Hotels and Resorts is located on Ma...                     5
# 27  The hotel is located on ITPL Road in Whitefiel...                     5
# 29  The hotel is located in Kodihalli, Bengaluru, ...                     5
# 32  The Leela Palace Kempinki Bangalore is situate...                     5
# 33  Situated in Bangalore , this property offers a...                     5
#
# ...

# %%
json=StarRating.to_json(r'Desktop//bengaluru_starrating.json')
