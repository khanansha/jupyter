# %%
import numpy as np
import pandas as pd
import itertools
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
from pandas.io.json import json_normalize
import json

# %%
with open('C:/Users/akhan.extern/Desktop/jsondata/doctors.json',encoding="utf8") as json_data:
    sample_object = json.load(json_data)

df = pd.io.json.json_normalize(sample_object)
df.columns = df.columns.map(lambda x: x.split(".")[-1])

print(df.shape)
# Out:
# (10, 48)

# %%
df
# Out:
#                    doctorId                               zoyloId  \
# 0  5a26e790ca07621fcc69ed6a  ff92023c-dc05-4f13-861c-1efda32f6674
# 1  5a26e7d0ca07621fcc69f2a8  af06a4b6-28b5-b000-88e8-368840550ff9
# 2  5a26e614ca07621fcc69cc2e  11619433-661b-641a-0051-c3740ffa2f2a
# 3  5a26e661ca07621fcc69d32d  669ce179-7279-edb7-da09-5752e8e4204d
# 4  5a26e534ca07621fcc69b6fd  e32285de-ecf1-1baa-1f32-e1889f182039
# 5  5a26e859ca07621fcc69fda7  2193a2aa-3ff0-0f50-d99b-7f77143ce385
# 6  5a26e722ca07621fcc69e40e  f788940e-b4a8-262e-00bc-2e821eb79b2e
# 7  5a26e7f2ca07621fcc69f56e  072293b1-b8eb-9fda-c159-40c9473fcd08
# 8  5a26e592ca07621fcc69c006  870424f6-07a2-a729-bac0-7bd30acd984d
# 9  5a26e572ca07621fcc69bd09  842346c8-f916-bd3a-470c-2279ee5e898c
#
#                      userId                    fullName  gender  \
# 0  5a26e03324d4540fc0cfeb68             Dr Kavin J Shah    Male
# 1  5a26df2524d4540fc0cf8d45             Dr Sonal K Shah  Female
# 2  5a26dfab24d4540fc0cfc61c       Dr Hardik Jayesh Shah    Male
# 3  5a26df0d24d4540fc0cf7c82              Dr Sayali Naik  Female
# 4  5a26df0f24d4540fc0cf7e13            Dr Sayali S Naik  Female
# 5  5a26df0624d4540fc0cf7677     Dr Shraddha Manoj Mange  Female
# 6  5a26df1524d4540fc0cf8274              Dr Mansi Desai  Female
# 7  5a26df1824d4540fc0cf8472              Dr Ameya Dalvi    Male
# 8  5a26def324d4540fc0cf61cc        Dr Shali Sanjay Shah  Female
# 9  5a26e03f24d4540fc0cfee09  Dr Amruta Harish Kadganche  Female
#
#                     dateOfBirth phoneNumber emailId zoyloCharge  zoyloRating  \
# 0  1970-01-01T00:00:00.000+0000                            None            5
# 1  1970-01-01T00:00:00.000+0000                            None            5
# 2  1983-09-04T18:30:00.000+0000                            None            5
# 3  1970-01-01T00:00:00.000+0000                            None            5
# 4                          None                            None            5
# 5                          None                            None            5
# 6                          None                            None            5
# 7  1970-01-01T00:00:00.000+0000                            None            5
# 8  1987-09-09T00:00:00.000+0000                            None            5
# 9                          None                            None            5
#
#    ...                                     seoInformation  \
# 0  ...  [{'seoMetadata': [{'languageId': '', 'language...
# 1  ...  [{'seoMetadata': [{'languageId': '', 'language...
# 2  ...  [{'seoMetadata': [{'languageId': '5a26dee6d8f6...
# 3  ...  [{'seoMetadata': [{'languageId': '', 'language...
# 4  ...  [{'seoMetadata': [{'languageId': '', 'language...
# 5  ...  [{'seoMetadata': [{'languageId': '5a26dee6d8f6...
# 6  ...  [{'seoMetadata': [{'languageId': '', 'language...
# 7  ...  [{'seoMetadata': [{'languageId': '', 'language...
# 8  ...  [{'seoMetadata': [{'languageId': '', 'language...
# 9  ...  [{'seoMetadata': [{'languageId': '', 'language...
#
#                   seoSlugUniqueId aboutText onlineFlag  \
# 0             kavin-j-shah-dental      None       None
# 1             sonal-k-shah-dental      None       None
# 2       hardik-jayesh-shah-dental      None       None
# 3              sayali-naik-dental      None       None
# 4                  sayali-s-naik-      None       None
# 5     shraddha-manoj-mange-dental      None       None
# 6              mansi-desai-dental      None       None
# 7              ameya-dalvi-dental      None       None
# 8        shali-sanjay-shah-dental      None       None
# 9  amruta-harish-kadganche-dental      None       None
#
#   chatNormalConsultationFee chatEnableHr zoyloPreferred  monthlySchedule  \
# 0                      None         None          False            False
# 1                      None         None          False            False
# 2                      None         None          False            False
# 3                      None         None          False            False
# 4                      None         None          False            False
# 5                      None         None          False            False
# 6                      None         None          False            False
# 7                      None         None          False            False
# 8                      None         None          False            False
# 9                      None         None          False            False
#
#    weeklySchedule  videoNormalConsultationFee
# 0            True                        None
# 1            True                        None
# 2            True                        None
# 3            True                        None
# 4            True                        None
# 5            True                        None
# 6            True                        None
# 7            True                        None
# 8            True                        None
# 9            True                        None
#
# [10 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['doctorId', 'zoyloId', 'userId', 'fullName', 'gender', 'dateOfBirth',
#        'phoneNumber', 'emailId', 'zoyloCharge', 'zoyloRating', 'activeFlag',
#        'specializationName', 'qualificationName', 'serviceProviderId',
#        'serviceProviderName', 'serviceProviderShortName',
#        'serviceProviderSearchName', 'homeVisitFlag',
#        'homeVisitServiceRangeInKms', 'onlineConsultationFlag', 'startDay',
#        'endDay', 'dayCode', 'facilityList', 'languageInfo', 'imageInfo',
#        'distance', 'practiceStartDate', 'practiceStartYear', 'experience',
#        'consultationInfo', 'gpsLatitude', 'gpsLongitude', 'favourite',
#        'addressList', 'normalConsultationFee', 'distanceValue', 'paymentMode',
#        'seoInformation', 'seoSlugUniqueId', 'aboutText', 'onlineFlag',
#        'chatNormalConsultationFee', 'chatEnableHr', 'zoyloPreferred',
#        'monthlySchedule', 'weeklySchedule', 'videoNormalConsultationFee'],
#       dtype='object')

# %%
from sqlalchemy import create_engine
