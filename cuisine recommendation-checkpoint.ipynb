# %%
import numpy as np
import pandas as pd
import requests
from pandas.io.json import json_normalize
import json

# %%
df=pd.read_csv('C:/Users/akhan.extern/Desktop/jsondata/modified_zomato_review.csv')

# %%
df
# Out:
#        Unnamed: 0               review_id                 user_id  \
# 0               0  V93SYj2OLh5m9Cquzf-7kg  ZwVz20be-hOZnyAbevyMyQ
# 1               1  vNTFadc6T9HeH3Qa78dc_Q  91TB-gzcNyxFh46TL0pmnQ
# 2               2  SXRFBCt5eXCBF7TlI7UG6Q  Y_QBiZpATJoz8hKUfYF66A
# 3               3  CqMNjtG0hNZGhDw4RDE-zw  _Jg-IA0M-GSjBlGu-wmejg
# 4               4  5hZLouGEW4wm6BTJ5aNUNw  1CqkFliipv_X15WYn5aPfg
# ...           ...                     ...                     ...
# 26601       26601  AnzRxb0iE5OtDj7cMitFeg  iDlkZO2iILS8Jwfdy7DP9A
# 26602       26602  GHK2LvwhLTQLb2-LY7H48w  5monCcK5b_sRvUpOk0H1Sw
# 26603       26603  qwLk-DtBdqtzIt_-67L2yQ  llXWc7py2mDQwZrNrogSDg
# 26604       26604  gxe6kdSqgcvC8Fo4o7GWiA  mRaaWyAFSwYGOT40T1-T9Q
# 26605       26605  jPCXuSBbI_cPocgoNBhdkg  V6BjjQICDO4q7TT3ZhaPWw
#
#        business_id                                               text  stars  \
# 0         18433909  Came here while in town for a country concert....    4.0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'review_id', 'user_id', 'business_id', 'text', 'stars',
#        'date'],
#       dtype='object')

# %%
data=pd.read_csv('C:/Users/akhan.extern/Desktop/jsondata/zomato.csv',encoding = "ISO-8859-1", engine='python')

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...
