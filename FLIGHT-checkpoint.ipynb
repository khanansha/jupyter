# %%
import numpy as np
import pandas as pd
import itertools
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
from pandas.io.json import json_normalize
import json

# %%
with open('C:/Users/akhan.extern/Desktop/jsondata/flight_search.json') as json_data:
    sample_object = json.load(json_data)

df = pd.io.json.json_normalize(sample_object)
df.columns = df.columns.map(lambda x: x.split(".")[-1])

print(df.shape)
# Out:
# (42, 52)

# %%
df.columns
# Out:
# Index(['FlightSegments', 'IntOnward', 'IntReturn', 'IntMulti', 'Provider',
#        'PartnerId', 'AffiliateId', 'FlightUId', 'IsGSTMandatory',
#        'AirlineRemark', 'IsLCC', 'IsHoldAllowed', 'validatingCarrier',
#        'ActualBaseFare', 'Tax', 'STax', 'SCharge', 'TDiscount',
#        'TPartnerCommission', 'NetFare', 'Conveniencefee', 'ConveniencefeeType',
#        'NetFares', 'Commission', 'CommissionType', 'TCharge', 'TMarkup',
#        'TSdiscount', 'FareAry', 'OCTax', 'PartnerFee', 'PLBEarned', 'TdsOnPLB',
#        'Bonus', 'TotalFare', 'ResponseStatus', 'Status', 'IsGSTMandatory',
#        'Message', 'RequiredFields', 'Id', 'Key', 'TravelClass', 'Mode',
#        'Source', 'Destination', 'Adults', 'Children', 'Infants', 'DepartDate',
#        'ReturnDate', 'MultiCityearch'],
#       dtype='object')

# %%
df
# Out:
#                                        FlightSegments IntOnward IntReturn  \
# 0   [{'AirEquipType': 'SG', 'ArrivalAirportCode': ...      None      None
# 1   [{'AirEquipType': 'SG', 'ArrivalAirportCode': ...      None      None
# 2   [{'AirEquipType': 'SG', 'ArrivalAirportCode': ...      None      None
# 3   [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 4   [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 5   [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 6   [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 7   [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 8   [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 9   [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 10  [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 11  [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 12  [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 13  [{'AirEquipType': 'SG', 'ArrivalAirportCode': ...      None      None
# 14  [{'AirEquipType': 'SG', 'ArrivalAirportCode': ...      None      None
# 15  [{'AirEquipType': 'SG', 'ArrivalAirportCode': ...      None      None
# 16  [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 17  [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 18  [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 19  [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 20  [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 21  [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 22  [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 23  [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 24  [{'AirEquipType': '6E', 'ArrivalAirportCode': ...      None      None
# 25  [{'AirEquipType': 'UK', 'ArrivalAirportCode': ...      None      None
# 26  [{'AirEquipType': 'UK', 'ArrivalAirportCode': ...      None      None
# 27  [{'AirEquipType': 'UK', 'ArrivalAirportCode': ...      None      None
# 28  [{'AirEquipType': 'UK', 'ArrivalAirportCode': ...      None      None
# 29  [{'AirEquipType': 'UK', 'ArrivalAirportCode': ...      None      None
# 30  [{'AirEquipType': 'UK', 'ArrivalAirportCode': ...      None      None
# 31  [{'AirEquipType': 'UK', 'ArrivalAirportCode': ...      None      None
# 32  [{'AirEquipType': 'UK', 'ArrivalAirportCode': ...      None      None
# 33  [{'AirEquipType': 'UK', 'ArrivalAirportCode': ...      None      None
# 34  [{'AirEquipType': 'UK', 'ArrivalAirportCode': ...      None      None
# 35  [{'AirEquipType': 'UK', 'ArrivalAirportCode': ...      None      None
# 36  [{'AirEquipType': 'UK', 'ArrivalAirportCode': ...      None      None
# 37  [{'AirEquipType': 'UK', 'ArrivalAirportCode': ...      None      None
# 38  [{'AirEquipType': 'UK', 'ArrivalAirportCode': ...      None      None
# 39  [{'AirEquipType': 'UK', 'ArrivalAirportCode': ...      None      None
# 40  [{'AirEquipType': 'SG', 'ArrivalAirportCode': ...      None      None
# 41  [{'AirEquipType': 'SG', 'ArrivalAirportCode': ...      None      None
#
#    IntMulti                  Provider PartnerId AffiliateId FlightUId  \
# 0      None  IFhrhEeSr7C9ff620/F6qg==      None        None      ET-0
# 1      None  IFhrhEeSr7C9ff620/F6qg==      None        None      ET-1
# 2      None  IFhrhEeSr7C9ff620/F6qg==      None        None      ET-2
# 3      None  IFhrhEeSr7C9ff620/F6qg==      None        None      ET-3
# 4      None  IFhrhEeSr7C9ff620/F6qg==      None        None      ET-4
# 5      None  IFhrhEeSr7C9ff620/F6qg==      None        None      ET-5
# 6      None  IFhrhEeSr7C9ff620/F6qg==      None        None      ET-6
# 7      None  IFhrhEeSr7C9ff620/F6qg==      None        None      ET-7
# 8      None  IFhrhEeSr7C9ff620/F6qg==      None        None      ET-8
# 9      None  IFhrhEeSr7C9ff620/F6qg==      None        None      ET-9
# 10     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-10
# 11     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-11
# 12     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-12
# 13     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-13
# 14     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-14
# 15     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-15
# 16     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-16
# 17     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-17
# 18     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-18
# 19     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-19
# 20     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-20
# 21     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-21
# 22     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-22
# 23     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-23
# 24     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-24
# 25     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-25
# 26     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-26
# 27     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-27
# 28     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-28
# 29     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-29
# 30     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-30
# 31     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-31
# 32     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-32
# 33     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-33
# 34     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-34
# 35     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-35
# 36     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-36
# 37     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-37
# 38     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-38
# 39     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-39
# 40     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-40
# 41     None  IFhrhEeSr7C9ff620/F6qg==      None        None     ET-41
#
#     IsGSTMandatory AirlineRemark  ...  TravelClass    Mode Source  \
# 0            False          None  ...         None  Single    HYD
# 1            False          None  ...         None  Single    HYD
# 2            False          None  ...         None  Single    HYD
# 3            False          None  ...         None  Single    HYD
# 4            False          None  ...         None  Single    HYD
# 5            False          None  ...         None  Single    HYD
# 6            False          None  ...         None  Single    HYD
# 7            False          None  ...         None  Single    HYD
# 8            False          None  ...         None  Single    HYD
# 9            False          None  ...         None  Single    HYD
# 10           False          None  ...         None  Single    HYD
# 11           False          None  ...         None  Single    HYD
# 12           False          None  ...         None  Single    HYD
# 13           False          None  ...         None  Single    HYD
# 14           False          None  ...         None  Single    HYD
# 15           False          None  ...         None  Single    HYD
# 16           False          None  ...         None  Single    HYD
# 17           False          None  ...         None  Single    HYD
# 18           False          None  ...         None  Single    HYD
# 19           False          None  ...         None  Single    HYD
# 20           False          None  ...         None  Single    HYD
# 21           False          None  ...         None  Single    HYD
# 22           False          None  ...         None  Single    HYD
# 23           False          None  ...         None  Single    HYD
# 24           False          None  ...         None  Single    HYD
# 25           False          None  ...         None  Single    HYD
# 26           False          None  ...         None  Single    HYD
# 27           False          None  ...         None  Single    HYD
# 28           False          None  ...         None  Single    HYD
# 29           False          None  ...         None  Single    HYD
# 30           False          None  ...         None  Single    HYD
# 31           False          None  ...         None  Single    HYD
# 32           False          None  ...         None  Single    HYD
# 33           False          None  ...         None  Single    HYD
# 34           False          None  ...         None  Single    HYD
# 35           False          None  ...         None  Single    HYD
# 36           False          None  ...         None  Single    HYD
# 37           False          None  ...         None  Single    HYD
# 38           False          None  ...         None  Single    HYD
# 39           False          None  ...         None  Single    HYD
# 40           False          None  ...         None  Single    HYD
# 41           False          None  ...         None  Single    HYD
#
#     Destination  Adults  Children  Infants           DepartDate  \
# 0           BLR       1         0        0  2020-03-21T00:00:00
# 1           BLR       1         0        0  2020-03-21T00:00:00
# 2           BLR       1         0        0  2020-03-21T00:00:00
# 3           BLR       1         0        0  2020-03-21T00:00:00
# 4           BLR       1         0        0  2020-03-21T00:00:00
# 5           BLR       1         0        0  2020-03-21T00:00:00
# 6           BLR       1         0        0  2020-03-21T00:00:00
# 7           BLR       1         0        0  2020-03-21T00:00:00
# 8           BLR       1         0        0  2020-03-21T00:00:00
# 9           BLR       1         0        0  2020-03-21T00:00:00
# 10          BLR       1         0        0  2020-03-21T00:00:00
# 11          BLR       1         0        0  2020-03-21T00:00:00
# 12          BLR       1         0        0  2020-03-21T00:00:00
# 13          BLR       1         0        0  2020-03-21T00:00:00
# 14          BLR       1         0        0  2020-03-21T00:00:00
# 15          BLR       1         0        0  2020-03-21T00:00:00
# 16          BLR       1         0        0  2020-03-21T00:00:00
# 17          BLR       1         0        0  2020-03-21T00:00:00
# 18          BLR       1         0        0  2020-03-21T00:00:00
# 19          BLR       1         0        0  2020-03-21T00:00:00
# 20          BLR       1         0        0  2020-03-21T00:00:00
